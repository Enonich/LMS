# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv()
mykey = os.getenv("llamaParse")

# %%
from llama_cloud_services import LlamaExtract
from pydantic import BaseModel, Field
from typing import List

# Initialize extractor client
extractor = LlamaExtract(api_key=mykey)

# Define schema for a single question
class Question(BaseModel):
    question_text: str = Field(description="The text of the question")
    options: List[str] = Field(
        description="The answer choices for the question with the option_id (empty if not MCQ)"
    )
    answer: str = Field(description="The correct answer, sometimes the answers are in a table format so map it to the respective question (eg. A. Processor)")
    department: str = Field(description="The department that will use the question")
    question_type: str = Field(
        description="Type of question, e.g. 'MCQ', 'Fill-in', 'True/False'"
    )

# Wrap multiple questions
class QuestionSet(BaseModel):
    questions: List[Question] = Field(description="A list of extracted questions")

# %%
from llama_cloud.types import ExtractConfig, ExtractMode

config = ExtractConfig(use_reasoning=True, 
                      extraction_mode=ExtractMode.MULTIMODAL
                      )

# %%
# Create extraction agent
agent = extractor.create_agent(
    name="question-parser_v1",
    config=config,
    data_schema=QuestionSet
)

# %%
# Enhanced version of your original code
# agent = extractor.create_agent(
#     name="question-parser_v1",
#     data_schema=QuestionSet,  # Changed from Question to QuestionSet
#     extraction_instruction="""
#     Extract ALL questions from the ENTIRE document. 
#     Process every page thoroughly and don't stop after finding a few questions.
#     Look for all types of questions: MCQ, fill-in-the-blank, true/false, short answer.
#     Include all answer choices and map answers to questions.
#     """
# )

# %%
# Step 2: Use LlamaExtract to structure the extracted text
result = agent.extract("./CS_Questions.pdf")
print(result.data)
# Out:
# Uploading files: 100%|██████████| 1/1 [00:06<00:00,  6.62s/it]
# Uploading files: 100%|██████████| 1/1 [00:06<00:00,  6.62s/it]]
# Creating extraction jobs: 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]
# Creating extraction jobs: 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]
# Extracting files: 100%|██████████| 1/1 [02:35<00:00, 155.66s/it]
# {'questions': [{'question_text': 'UNIVAC is', 'options': ['A) Universal Automatic Computer', 'B) Universal Array Computer', 'C) Unique Automatic Computer', 'D) Unvalued Automatic Computer'], 'answer': 'A) Universal Automatic Computer', 'department': '', 'question_type': 'MCQ'}, {'question_text': 'The basic operations performed by a computer are', 'options': ['A) Arithmetic operation', 'B) Logical operation', 'C) Storage and relative', 'D) All the above'], 'answer': 'D) All the above', 'department': '', 'question_type': 'MCQ'}, {'question_text': 'The two major types of computer chips are', 'options': ['A) External memory chip', 'B) Primary memory chip', 'C) Microprocessor chip', 'D) Both b and c'], 'answer': 'D) Both b and c', 'department': '', 'question_type': 'MCQ'}, {'question_text': 'Microprocessors as switching devices are for which generation computers', 'options': ['A) First Generation', 'B) Second Generation', 'C) Third Generation', 'D) Fourth Generation'], 'answer': 'D) Fourth Generation', 'department': '', 'question_type': 'MCQ'}, {'question_text': 'What is the main difference between a mainframe and a super computer?', 'options': ['A) Super computer is much larger than mainframe computers', 'B) Super computers are much smaller than mainframe computers', 'C) Supercomputers are focused to execute few programs as fast as possible while mainframe uses its power to execute as many programs concurrently', 'D) Supercomputers are focused to execute as many programs as possible while mainframe uses its power to execute few programs as fast as possible.'], 'answer': 'C) Supercomputers are focused to execute few programs as fast as possible while mainframe uses its power to execute as many programs concurrently', 'department': '', 'question_type': 'MCQ'}, {'question_text': 'ASCII and EBCDIC are the popular character coding systems. What does EBCDIC stand for?', 'options': ['A) Extended Binary Coded Decimal Interchange Code', 'B) Extended Bit Code Decimal Interchange Code', 'C) Extended Bit Case Decimal Interchange Code', 'D) Extended Binary Case Decimal Interchange Code'], 'answer': 'A) Extended Binary Coded Decimal Interchange Code', 'department': '', 'question_type': 'MCQ'}, {'question_text': 'The brain of any computer system is', 'options': ['A) ALU', 'B) Memory', 'C) CPU', 'D) Control unit'], 'answer': 'C) CPU', 'department': '', 'question_type': 'MCQ'}, {'question_text': 'Storage capacity of magnetic disk depends on', 'options': ['A) tracks per inch of surface', 'B) bits per inch of tracks', 'C) disk pack in disk surface', 'D) All of above'], 'answer': 'D) All of above', 'department': '', 'question_type': 'MCQ'}, {'question_text': 'The two kinds of main memory are:', 'options': ['A) Primary and secondary', 'B) Random and sequential', 'C) ROM and RAM', 'D) All of above'], 'answer': 'C) ROM and RAM', 'department': '', 'question_type': 'MCQ'}, {'question_text': 'A storage area used to store data to a compensate for the difference in speed at which the different units can handle data is', 'options': ['A) Memory', 'B) Buffer', 'C) Accumulator', 'D) Address'], 'answer': 'B) Buffer', 'department': '', 'question_type': 'MCQ'}, {'question_text': 'The computer size was very large in', 'options': ['A) First Generation', 'B) Second Generation', 'C) Third Generation', 'D) Fourth Generation'], 'answer': 'A) First Generation', 'department': '', 'question_type': 'MCQ'}, {'question_text': 'A name or number used to identify storage location devices?', 'options': ['A) A byte', 'B) A record', 'C) An address', 'D) All of above'], 'answer': 'C) An address', 'department': '', 'question_type': 'MCQ'}, {'question_text': 'Which of the following is not computer language?', 'options': ['A) High level language', 'B) Medium level language', 'C) Low level language', 'D) All of the above'], 'answer': 'B) Medium level language', 'department': '', 'question_type': 'MCQ'}, {'question_text': 'Reading data is performed in magnetic disk by', 'options': ['A) Re ...
# Uploading files: 100%|██████████| 1/1 [00:06<00:00,  6.59s/it]
#
# Creating extraction jobs: 100%|██████████| 1/1 [00:01<00:00,  1.71s/it]
#
# Extracting files: 100%|██████████| 1/1 [00:38<00:00, 38.05s/it]

# %%
result.data
# Out:
# {'questions': [{'question_text': 'UNIVAC is',
#    'options': ['A) Universal Automatic Computer',
#     'B) Universal Array Computer',
#     'C) Unique Automatic Computer',
#     'D) Unvalued Automatic Computer'],
#    'answer': 'A) Universal Automatic Computer',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'The basic operations performed by a computer are',
#    'options': ['A) Arithmetic operation',
#     'B) Logical operation',
#     'C) Storage and relative',
#     'D) All the above'],
#    'answer': 'D) All the above',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'The two major types of computer chips are',
#    'options': ['A) External memory chip',
#     'B) Primary memory chip',
#     'C) Microprocessor chip',
#     'D) Both b and c'],
#    'answer': 'D) Both b and c',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'Microprocessors as switching devices are for which generation computers',
#    'options': ['A) First Generation',
#     'B) Second Generation',
#     'C) Third Generation',
#     'D) Fourth Generation'],
#    'answer': 'D) Fourth Generation',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'What is the main difference between a mainframe and a super computer?',
#    'options': ['A) Super computer is much larger than mainframe computers',
#     'B) Super computers are much smaller than mainframe computers',
#     'C) Supercomputers are focused to execute few programs as fast as possible while mainframe uses its power to execute as many programs concurrently',
#     'D) Supercomputers are focused to execute as many programs as possible while mainframe uses its power to execute few programs as fast as possible.'],
#    'answer': 'C) Supercomputers are focused to execute few programs as fast as possible while mainframe uses its power to execute as many programs concurrently',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'ASCII and EBCDIC are the popular character coding systems. What does EBCDIC stand for?',
#    'options': ['A) Extended Binary Coded Decimal Interchange Code',
#     'B) Extended Bit Code Decimal Interchange Code',
#     'C) Extended Bit Case Decimal Interchange Code',
#     'D) Extended Binary Case Decimal Interchange Code'],
#    'answer': 'A) Extended Binary Coded Decimal Interchange Code',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'The brain of any computer system is',
#    'options': ['A) ALU', 'B) Memory', 'C) CPU', 'D) Control unit'],
#    'answer': 'C) CPU',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'Storage capacity of magnetic disk depends on',
#    'options': ['A) tracks per inch of surface',
#     'B) bits per inch of tracks',
#     'C) disk pack in disk surface',
#     'D) All of above'],
#    'answer': 'D) All of above',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'The two kinds of main memory are:',
#    'options': ['A) Primary and secondary',
#     'B) Random and sequential',
#     'C) ROM and RAM',
#     'D) All of above'],
#    'answer': 'C) ROM and RAM',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'A storage area used to store data to a compensate for the difference in speed at which the different units can handle data is',
#    'options': ['A) Memory', 'B) Buffer', 'C) Accumulator', 'D) Address'],
#    'answer': 'B) Buffer',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'The computer size was very large in',
#    'options': ['A) First Generation',
#     'B) Second Generation',
#     'C) Third Generation',
#     'D) Fourth Generation'],
#    'answer': 'A) First Generation',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'A name or number used to identify storage location devices?',
#    'options': ['A) A byte', 'B) A record', 'C) An address', 'D) All of above'],
#    'answer': 'C) An address',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'Which of the following is not computer language?',
#    'options': ['A) High level language',
#     'B) Medium level language',
#     'C) Low level language',
#     'D) All of the above'],
#    'answer': 'B) Medium level language',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'Reading data is performed in magnetic disk by',
#    'options': ['A) Read/write leads',
#     'B) Sectors',
#     'C) Track',
#     'D) Lower surface'],
#    'answer': 'A) Read/write leads',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'IBM 7000 digital computer',
#    'options': ['A) Belongs to second generation',
#     'B) Uses VLSI',
#     'C) Employs semiconductor memory',
#     'D) Has modular constructions'],
#    'answer': 'D) Has modular constructions',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'Which of the following is not electro-mechanical computer?',
#    'options': ['A) Mark I', 'B) ABC', 'C) Zuse', 'D) UNIVAC'],
#    'answer': 'D) UNIVAC',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': "The term 'computer' is derived from",
#    'options': ['A) Greek language',
#     'B) Sanskrit language',
#     'C) Latin language',
#     'D) German language'],
#    'answer': 'C) Latin language',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'Which of the following are the two main components of the CPU?',
#    'options': ['Control Unit and Registers',
#     'Registers and Main Memory',
#     'Control unit and ALU',
#     'ALU and bus'],
#    'answer': 'Control unit and ALU',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'Fifth generation computer is also known as',
#    'options': ['Knowledge information processing system',
#     'Very large scale integration',
#     'Both of above',
#     'None of above'],
#    'answer': 'Knowledge information processing system',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'Second Generation computers were developed during',
#    'options': ['1949 to 1955', '1956 to 1965', '1965 to 1970', '1970 to 1990'],
#    'answer': '1956 to 1965',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'What is the name of the computer terminal which gives paper printout?',
#    'options': ['Display screen',
#     'Soft copy terminal',
#     'Hard copy terminal',
#     'Plotter'],
#    'answer': 'Hard copy terminal',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'Programs are executed on the basis of a priority number in a',
#    'options': ['Batch processing system',
#     'Multiprogramming',
#     'Time sharing',
#     'None of these'],
#    'answer': 'Multiprogramming',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'When was Apple Macintosh II microcomputer introduced in the market?',
#    'options': ['1964', '1970', '1983', '1986'],
#    'answer': '1983',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': "When was the world's first laptop computer introduced in the market and by whom?",
#    'options': ['Hewlett-Packard',
#     'Epson, 1981',
#     'Laplink traveling software In1982',
#     'Tandy model-2000, 1985'],
#    'answer': 'Epson, 1981',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': "Today's computer giant IBM was earlier known by different name which was changed in 1924. What was that name?",
#    'options': ['Computer Tabulating Recording Co.',
#     'The Tabulator Ltd.',
#     'International Computer Ltd.',
#     'None of above'],
#    'answer': 'Computer Tabulating Recording Co.',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'The personnel who deals with the computer and its management put together are called',
#    'options': ['Software', 'Human ware', 'Firmware', 'Hardware'],
#    'answer': 'Human ware',
#    'department': '',
#    'question_type': 'MCQ'},
#   {'question_text': 'Which of the following is input device?',
#    'options': ['scanner', 'speaker', 'monitor', 'projector'],
#    'answer': 'scanner',
#    'department': '',
#    'question_type': 'MCQ'}]}

# %%
# Extract from PDF
result = agent.extract("./biolset2.pdf")

# Preview structured output
print(result.data)
# Out:
# {'questions': [{'question_text': 'The adult human of average age and size has approximately how many quarts of blood?', 'options': ['4', '6', '8', '10'], 'answer': '6', 'department': 'Biology', 'question_type': 'MCQ'}, {'question_text': 'Once the erythrocytes enter the blood in humans, it is estimated that they have an average lifetime of how many days?', 'options': ['10 days', '120 days', '200 days', '360 days'], 'answer': '120 days', 'department': 'Biology', 'question_type': 'MCQ'}, {'question_text': 'Which mechanisms are important in the death of erythrocytes in human blood?', 'options': ['phagocytosis', 'hemolysis', 'mechanical damage', 'all of the above'], 'answer': 'all of the above', 'department': 'Biology', 'question_type': 'MCQ'}, {'question_text': 'Surplus red blood cells, needed to meet an emergency, are MAINLY stored in what organ of the human body?', 'options': ['pancreas', 'spleen', 'liver', 'kidneys'], 'answer': 'spleen', 'department': 'Biology', 'question_type': 'MCQ'}, {'question_text': 'When a human donor gives a pint of blood, it usually requires how many weeks for the body reserve of red corpuscles to be replaced?', 'options': ['1 week', '3 weeks', '7 weeks', '21 weeks'], 'answer': '7 weeks', 'department': 'Biology', 'question_type': 'MCQ'}, {'question_text': "There are three substances found in human blood which carry oxygen and which begin with the letter 'H'. Name two of these substances.", 'options': [], 'answer': 'Hemoglobin, Hemocyanin, Hemerythrin', 'department': 'Biology', 'question_type': 'Short Answer'}, {'question_text': 'The several types of white blood cells are sometime collectively referred to as:', 'options': ['erythrocytes', 'leukocytes', 'erythroblasts', 'thrombocytes'], 'answer': 'leukocytes', 'department': 'Biology', 'question_type': 'MCQ'}, {'question_text': 'The condition in which there is a decrease in the number of white blood cells in humans is known as:', 'options': ['leukocytosis', 'leukopenia', 'leukemia', 'leukohyperia'], 'answer': 'leukopenia', 'department': 'Biology', 'question_type': 'MCQ'}, {'question_text': 'The smallest of the formed elements of the blood are the:', 'options': ['white cells', 'red cells', 'platelets', 'erythrocytes'], 'answer': 'platelets', 'department': 'Biology', 'question_type': 'MCQ'}, {'question_text': 'Which of the following statements concerning platelets is INCORRECT. Platelets:', 'options': ['contain DNA', 'are roughly disk-shaped', 'have little ability to synthesize proteins', 'are between 1/2 and 1/3 the diameter of the red cell'], 'answer': 'contain DNA', 'department': 'Biology', 'question_type': 'MCQ'}]}

# %%
result.data
# Out:
# {'questions': [{'question_text': 'The adult human of average age and size has approximately how many quarts of blood?',
#    'options': ['4', '6', '8', '10'],
#    'answer': '6',
#    'department': 'Biology',
#    'question_type': 'MCQ'},
#   {'question_text': 'Once the erythrocytes enter the blood in humans, it is estimated that they have an average lifetime of how many days?',
#    'options': ['10 days', '120 days', '200 days', '360 days'],
#    'answer': '120 days',
#    'department': 'Biology',
#    'question_type': 'MCQ'},
#   {'question_text': 'Which mechanisms are important in the death of erythrocytes in human blood?',
#    'options': ['phagocytosis',
#     'hemolysis',
#     'mechanical damage',
#     'all of the above'],
#    'answer': 'all of the above',
#    'department': 'Biology',
#    'question_type': 'MCQ'},
#   {'question_text': 'Surplus red blood cells, needed to meet an emergency, are MAINLY stored in what organ of the human body?',
#    'options': ['pancreas', 'spleen', 'liver', 'kidneys'],
#    'answer': 'spleen',
#    'department': 'Biology',
#    'question_type': 'MCQ'},
#   {'question_text': 'When a human donor gives a pint of blood, it usually requires how many weeks for the body reserve of red corpuscles to be replaced?',
#    'options': ['1 week', '3 weeks', '7 weeks', '21 weeks'],
#    'answer': '7 weeks',
#    'department': 'Biology',
#    'question_type': 'MCQ'},
#   {'question_text': "There are three substances found in human blood which carry oxygen and which begin with the letter 'H'. Name two of these substances.",
#    'options': [],
#    'answer': 'Hemoglobin, Hemocyanin, Hemerythrin',
#    'department': 'Biology',
#    'question_type': 'Short Answer'},
#   {'question_text': 'The several types of white blood cells are sometime collectively referred to as:',
#    'options': ['erythrocytes', 'leukocytes', 'erythroblasts', 'thrombocytes'],
#    'answer': 'leukocytes',
#    'department': 'Biology',
#    'question_type': 'MCQ'},
#   {'question_text': 'The condition in which there is a decrease in the number of white blood cells in humans is known as:',
#    'options': ['leukocytosis', 'leukopenia', 'leukemia', 'leukohyperia'],
#    'answer': 'leukopenia',
#    'department': 'Biology',
#    'question_type': 'MCQ'},
#   {'question_text': 'The smallest of the formed elements of the blood are the:',
#    'options': ['white cells', 'red cells', 'platelets', 'erythrocytes'],
#    'answer': 'platelets',
#    'department': 'Biology',
#    'question_type': 'MCQ'},
#   {'question_text': 'Which of the following statements concerning platelets is INCORRECT. Platelets:',
#    'options': ['contain DNA',
#     'are roughly disk-shaped',
#     'have little ability to synthesize proteins',
#     'are between 1/2 and 1/3 the diameter of the red cell'],
#    'answer': 'contain DNA',
#    'department': 'Biology',
#    'question_type': 'MCQ'}]}

# %%
from collections import defaultdict

dept_counters = defaultdict(int)  # keeps track of counters per department

for q in result.data['questions']:
    # Generate department prefix (e.g., BIO, GEO, MTH...)
    dept_prefix = q["department"][:3].upper()

    # Increment counter for this department
    dept_counters[dept_prefix] += 1

    # Create question_id like BIO-001
    q["question_id"] = f"{dept_prefix}-{dept_counters[dept_prefix]:03d}"

    # Add public_text for user display
    public_text = q["question_text"]
    if q["options"]:
        public_text += " Options: " + ", ".join(q["options"])
    q["public_text"] = public_text

# %%
result.data
# Out:
# {'questions': [{'question_text': 'The adult human of average age and size has approximately how many quarts of blood?',
#    'options': ['4', '6', '8', '10'],
#    'answer': '6',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-001',
#    'public_text': 'The adult human of average age and size has approximately how many quarts of blood? Options: 4, 6, 8, 10'},
#   {'question_text': 'Once the erythrocytes enter the blood in humans, it is estimated that they have an average lifetime of how many days.',
#    'options': ['10 days', '120 days', '200 days', '360 days'],
#    'answer': '120 days',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-002',
#    'public_text': 'Once the erythrocytes enter the blood in humans, it is estimated that they have an average lifetime of how many days. Options: 10 days, 120 days, 200 days, 360 days'},
#   {'question_text': 'Which mechanisms are important in the death of erythrocytes in human blood?',
#    'options': ['phagocytosis',
#     'hemolysis',
#     'mechanical damage',
#     'all of the above'],
#    'answer': 'all of the above',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-003',
#    'public_text': 'Which mechanisms are important in the death of erythrocytes in human blood? Options: phagocytosis, hemolysis, mechanical damage, all of the above'},
#   {'question_text': 'Surplus red blood cells, needed to meet an emergency, are MAINLY stored in what organ of the human body?',
#    'options': ['pancreas', 'spleen', 'liver', 'kidneys'],
#    'answer': 'spleen',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-004',
#    'public_text': 'Surplus red blood cells, needed to meet an emergency, are MAINLY stored in what organ of the human body? Options: pancreas, spleen, liver, kidneys'},
#   {'question_text': 'When a human donor gives a pint of blood, it usually requires how many weeks for the body RESERVE of red corpuscles to be replaced?',
#    'options': ['1 week', '3 weeks', '7 weeks', '21 weeks'],
#    'answer': '7 weeks',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-005',
#    'public_text': 'When a human donor gives a pint of blood, it usually requires how many weeks for the body RESERVE of red corpuscles to be replaced? Options: 1 week, 3 weeks, 7 weeks, 21 weeks'},
#   {'question_text': 'There are three substances found in human blood which carry oxygen and which begin with the letter "H". Name two of these substances.',
#    'options': [],
#    'answer': 'Hemoglobin, Hemocyanin, Hemerythrin',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-006',
#    'public_text': 'There are three substances found in human blood which carry oxygen and which begin with the letter "H". Name two of these substances.'},
#   {'question_text': 'The several types of white blood cells are sometimes collectively referred to as:',
#    'options': [],
#    'answer': '',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-007',
#    'public_text': 'The several types of white blood cells are sometimes collectively referred to as:'},
#   {'question_text': 'The condition in which there is a DECREASE in the number of white blood cells in humans is known as:',
#    'options': ['leukocytosis', 'leukopenia', 'leukemia', 'leukohyperia'],
#    'answer': 'leukopenia',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-008',
#    'public_text': 'The condition in which there is a DECREASE in the number of white blood cells in humans is known as: Options: leukocytosis, leukopenia, leukemia, leukohyperia'},
#   {'question_text': 'The smallest of the FORMED elements of the blood are the:',
#    'options': ['white cells', 'red cells', 'platelets', 'erythrocytes'],
#    'answer': 'platelets',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-009',
#    'public_text': 'The smallest of the FORMED elements of the blood are the: Options: white cells, red cells, platelets, erythrocytes'},
#   {'question_text': 'Which of the following statements concerning platelets is INCORRECT. Platelets:',
#    'options': ['contain DNA',
#     'are roughly disk-shaped',
#     'have little ability to synthesize proteins',
#     'are between 1/2 and 1/3 the diameter of the red cell'],
#    'answer': 'contain DNA',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-010',
#    'public_text': 'Which of the following statements concerning platelets is INCORRECT. Platelets: Options: contain DNA, are roughly disk-shaped, have little ability to synthesize proteins, are between 1/2 and 1/3 the diameter of the red cell'},
#   {'question_text': 'What is the primary function of the platelets in human blood?',
#    'options': [],
#    'answer': 'clotting or blocking leaks from blood vessels',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-011',
#    'public_text': 'What is the primary function of the platelets in human blood?'},
#   {'question_text': 'When a wound occurs in humans, the platelets in the blood activate a substance which starts the clotting process. The substance which starts the clotting is:',
#    'options': ['adenosine', 'histamine', 'lecithin', 'thrombin'],
#    'answer': 'Thrombin',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-012',
#    'public_text': 'When a wound occurs in humans, the platelets in the blood activate a substance which starts the clotting process. The substance which starts the clotting is: Options: adenosine, histamine, lecithin, thrombin'},
#   {'question_text': 'When looking at the cross section of the human tibia, one finds the RED marrow in the:',
#    'options': ['medullary cavity',
#     'cancellous bone',
#     'periosteum',
#     'epiphysis'],
#    'answer': 'medullary cavity',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-013',
#    'public_text': 'When looking at the cross section of the human tibia, one finds the RED marrow in the: Options: medullary cavity, cancellous bone, periosteum, epiphysis'},
#   {'question_text': 'Lengthening of long bones in humans occurs in a particular area of the bone. This area is called the:',
#    'options': ['medullary canal',
#     'cancellous bone',
#     'periosteum',
#     'epiphysis'],
#    'answer': 'epiphysis',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-014',
#    'public_text': 'Lengthening of long bones in humans occurs in a particular area of the bone. This area is called the: Options: medullary canal, cancellous bone, periosteum, epiphysis'},
#   {'question_text': 'The part of the human brain which is an important relay station for the sensory impulses and also is the origin of many of the involuntary acts of the eye such as the narrowing of the pupil in bright light is the:',
#    'options': ['hypothalamus', 'midbrain', 'corpus callosum', 'cerebellum'],
#    'answer': 'midbrain',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-015',
#    'public_text': 'The part of the human brain which is an important relay station for the sensory impulses and also is the origin of many of the involuntary acts of the eye such as the narrowing of the pupil in bright light is the: Options: hypothalamus, midbrain, corpus callosum, cerebellum'},
#   {'question_text': "In the human brain, body temperature, metabolism, heart rate, sexual development, sleep and the body's use of fat and water are influenced by this region of the brain. This region of the brain is the:",
#    'options': ['hypothalamus', 'midbrain', 'corpus callosum', 'cerebellum'],
#    'answer': 'hypothalamus',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-016',
#    'public_text': "In the human brain, body temperature, metabolism, heart rate, sexual development, sleep and the body's use of fat and water are influenced by this region of the brain. This region of the brain is the: Options: hypothalamus, midbrain, corpus callosum, cerebellum"},
#   {'question_text': 'In which cerebral lobes is the speech center located?',
#    'options': ['frontal', 'parietal', 'temporal', 'occipital'],
#    'answer': 'frontal',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-017',
#    'public_text': 'In which cerebral lobes is the speech center located? Options: frontal, parietal, temporal, occipital'},
#   {'question_text': 'In most axons, the myelin sheath is interrupted at intervals of about 1 millimeter or more. These interruptions are called the:',
#    'options': ['glial', 'nodes of Ranvier', 'collaterals', 'nodes of Babinet'],
#    'answer': 'nodes of Ranvier',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-018',
#    'public_text': 'In most axons, the myelin sheath is interrupted at intervals of about 1 millimeter or more. These interruptions are called the: Options: glial, nodes of Ranvier, collaterals, nodes of Babinet'},
#   {'question_text': 'Mosses and liverworts comprise this subdivision of plants. Name this plant subdivision.',
#    'options': [],
#    'answer': 'Bryophytes or Bryophyta',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-019',
#    'public_text': 'Mosses and liverworts comprise this subdivision of plants. Name this plant subdivision.'},
#   {'question_text': 'This disease, caused by infection with the gram-negative Yersinia pestis, is transmitted by fleas from rats to humans. What is the more common name for this disease?',
#    'options': [],
#    'answer': 'Bubonic Plague or Black Death',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-020',
#    'public_text': 'This disease, caused by infection with the gram-negative Yersinia pestis, is transmitted by fleas from rats to humans. What is the more common name for this disease?'},
#   {'question_text': 'In the mammalian body, this element plays many important roles, such as maintaining normal muscular contraction and blood coagulation, and is the most important element of bone salt. Name this element.',
#    'options': [],
#    'answer': 'Calcium',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-021',
#    'public_text': 'In the mammalian body, this element plays many important roles, such as maintaining normal muscular contraction and blood coagulation, and is the most important element of bone salt. Name this element.'},
#   {'question_text': 'What eight-letter name starting with the letter "O" is given to that branch of medical science concerned with the study of tumors?',
#    'options': [],
#    'answer': 'Oncology',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-022',
#    'public_text': 'What eight-letter name starting with the letter "O" is given to that branch of medical science concerned with the study of tumors?'},
#   {'question_text': 'In the more highly developed animals, such as humans, this gas is used to regulate the activity of the heart, the blood vessels, and the respiratory system. Working muscles produce a large amount of this substance. Narcosis due to this gas is characterized by mental disturbances which can include confusion, headache, low blood pressure, and hypothermia. Name this gas.',
#    'options': [],
#    'answer': 'Carbon Dioxide or CO2',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-023',
#    'public_text': 'In the more highly developed animals, such as humans, this gas is used to regulate the activity of the heart, the blood vessels, and the respiratory system. Working muscles produce a large amount of this substance. Narcosis due to this gas is characterized by mental disturbances which can include confusion, headache, low blood pressure, and hypothermia. Name this gas.'},
#   {'question_text': 'Cariology is the study of the:',
#    'options': ['human heart', 'tooth decay', 'kidneys', 'liver'],
#    'answer': 'tooth decay',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-024',
#    'public_text': 'Cariology is the study of the: Options: human heart, tooth decay, kidneys, liver'},
#   {'question_text': 'The larval form of butterflies and moths is more commonly known as what?',
#    'options': [],
#    'answer': 'caterpillar',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-025',
#    'public_text': 'The larval form of butterflies and moths is more commonly known as what?'},
#   {'question_text': 'Name the sac-like, blind pouch of the large intestine, situated below the level of the junction of the small intestine into the side of the large intestine. At the lower portion of this pouch one finds the appendix.',
#    'options': [],
#    'answer': 'Cecum or Caecum',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-026',
#    'public_text': 'Name the sac-like, blind pouch of the large intestine, situated below the level of the junction of the small intestine into the side of the large intestine. At the lower portion of this pouch one finds the appendix.'},
#   {'question_text': 'During the final stage of cell division, the mitotic apparatus disappears, the chromosomes become attenuated, the centrioles duplicate and split, the nuclear membrane becomes reconstituted and the nucleolus reappears. This phase of cell division is known as:',
#    'options': ['prophase', 'metaphase', 'anaphase', 'telophase'],
#    'answer': 'telophase',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-027',
#    'public_text': 'During the final stage of cell division, the mitotic apparatus disappears, the chromosomes become attenuated, the centrioles duplicate and split, the nuclear membrane becomes reconstituted and the nucleolus reappears. This phase of cell division is known as: Options: prophase, metaphase, anaphase, telophase'},
#   {'question_text': 'All cells of an organism find their lineage from a single fertilized cell. This single fertilized cell is called what?',
#    'options': [],
#    'answer': 'Zygote',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-028',
#    'public_text': 'All cells of an organism find their lineage from a single fertilized cell. This single fertilized cell is called what?'},
#   {'question_text': 'Name the clear watery liquid that surrounds the brain and spinal cord and fills the four cavities or ventricles of the brain.',
#    'options': [],
#    'answer': 'Cerebrospinal Fluid',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-029',
#    'public_text': 'Name the clear watery liquid that surrounds the brain and spinal cord and fills the four cavities or ventricles of the brain.'},
#   {'question_text': 'The order of insects which includes beetles is known as:',
#    'options': ['Coleoptera', 'Orthoptera', 'Hymenoptera', 'Diptera'],
#    'answer': 'Coleoptera',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-030',
#    'public_text': 'The order of insects which includes beetles is known as: Options: Coleoptera, Orthoptera, Hymenoptera, Diptera'},
#   {'question_text': 'This major protein component of connective tissue in mammals comprises most of the organic matter of skin, tendons, bones, and teeth, and occurs as fibrous inclusions in most other body structures. Is this material:',
#    'options': ['elastin', 'collagen', 'fatty acids', 'keratin'],
#    'answer': 'collagen',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-031',
#    'public_text': 'This major protein component of connective tissue in mammals comprises most of the organic matter of skin, tendons, bones, and teeth, and occurs as fibrous inclusions in most other body structures. Is this material: Options: elastin, collagen, fatty acids, keratin'},
#   {'question_text': "Sickle cell anemia and Huntington's chorea are both:",
#    'options': ['virus-related diseases',
#     'bacteria-related diseases',
#     'congenital disorders',
#     'none of the above'],
#    'answer': 'congenital disorders',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-032',
#    'public_text': "Sickle cell anemia and Huntington's chorea are both: Options: virus-related diseases, bacteria-related diseases, congenital disorders, none of the above"},
#   {'question_text': 'In most species of Paramecium there are how many contractile vacuoles?',
#    'options': ['one', 'two', 'three', 'four'],
#    'answer': 'two',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-033',
#    'public_text': 'In most species of Paramecium there are how many contractile vacuoles? Options: one, two, three, four'},
#   {'question_text': 'Name the outer portion of a stem or root, bounded externally by the epidermis, and internally by the cells of the pericycle.',
#    'options': [],
#    'answer': 'Cortex',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-034',
#    'public_text': 'Name the outer portion of a stem or root, bounded externally by the epidermis, and internally by the cells of the pericycle.'},
#   {'question_text': 'Costal cartilage:',
#    'options': ['attach the ribs to the sternum',
#     'cover the ends of the femur',
#     'is found in the pinna of the ear',
#     'forms the intervertebral disks of the backbone'],
#    'answer': 'attach the ribs to the sternum',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-035',
#    'public_text': 'Costal cartilage: Options: attach the ribs to the sternum, cover the ends of the femur, is found in the pinna of the ear, forms the intervertebral disks of the backbone'},
#   {'question_text': 'From which grandparent or grandparents did you inherit your mitochondria?',
#    'options': ["mother's parents",
#     'paternal grandfather',
#     'grand mothers',
#     'maternal grandmother'],
#    'answer': 'maternal grandmother',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-036',
#    'public_text': "From which grandparent or grandparents did you inherit your mitochondria? Options: mother's parents, paternal grandfather, grand mothers, maternal grandmother"},
#   {'question_text': 'Which of the following are NOT part of a neuron?',
#    'options': ['synapse', 'axon', 'Nissl bodies', 'dendrite'],
#    'answer': 'synapse',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-037',
#    'public_text': 'Which of the following are NOT part of a neuron? Options: synapse, axon, Nissl bodies, dendrite'},
#   {'question_text': 'The resting potential of a neuron is dependent on what two ions?',
#    'options': ['lead and calcium ions',
#     'calcium and phosphate ions',
#     'sodium and potassium ions',
#     'potassium and phosphate ions'],
#    'answer': 'sodium and potassium ions',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-038',
#    'public_text': 'The resting potential of a neuron is dependent on what two ions? Options: lead and calcium ions, calcium and phosphate ions, sodium and potassium ions, potassium and phosphate ions'},
#   {'question_text': 'Which of the following is NOT a type of neuron?',
#    'options': ['sensory', 'motor', 'association', 'stimulatory'],
#    'answer': 'stimulatory',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-039',
#    'public_text': 'Which of the following is NOT a type of neuron? Options: sensory, motor, association, stimulatory'},
#   {'question_text': 'Melatonin is produced by the:',
#    'options': ['skin'],
#    'answer': '',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-040',
#    'public_text': 'Melatonin is produced by the: Options: skin'},
#   {'question_text': 'Which of the following statements is TRUE of insulin?',
#    'options': ['secreted by the pancreas',
#     'a protein',
#     'involved in the metabolism of glucose',
#     'all of the above'],
#    'answer': 'all of the above',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-041',
#    'public_text': 'Which of the following statements is TRUE of insulin? Options: secreted by the pancreas, a protein, involved in the metabolism of glucose, all of the above'},
#   {'question_text': 'Select the hormone INCORRECTLY paired with its target.',
#    'options': ['TSH - thyroid gland',
#     'ACTH - anterior pituitary',
#     'LH - ovary or testis',
#     'MSH - melanocytes'],
#    'answer': 'MSH - melanocytes',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-042',
#    'public_text': 'Select the hormone INCORRECTLY paired with its target. Options: TSH - thyroid gland, ACTH - anterior pituitary, LH - ovary or testis, MSH - melanocytes'},
#   {'question_text': 'Which of the following tissues secrete hormones?',
#    'options': ['pancreas',
#     'ovaries',
#     'gastro-intestinal tract',
#     'all of the above'],
#    'answer': 'all of the above',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-043',
#    'public_text': 'Which of the following tissues secrete hormones? Options: pancreas, ovaries, gastro-intestinal tract, all of the above'},
#   {'question_text': 'Which of the following structures is directly attached to the ovary?',
#    'options': ['oviduct', 'uterus', 'suspensory ligaments', 'vagina'],
#    'answer': 'suspensory ligaments',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-044',
#    'public_text': 'Which of the following structures is directly attached to the ovary? Options: oviduct, uterus, suspensory ligaments, vagina'},
#   {'question_text': 'Fertilization of the ovum by the sperm usually occurs in the:',
#    'options': ['oviduct', 'vagina', 'uterus', 'ovary'],
#    'answer': 'oviduct',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-045',
#    'public_text': 'Fertilization of the ovum by the sperm usually occurs in the: Options: oviduct, vagina, uterus, ovary'},
#   {'question_text': 'The corpeus luteum secretes:',
#    'options': ['HCG', 'LH', 'FSH', 'progesterone'],
#    'answer': 'progesterone',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-046',
#    'public_text': 'The corpeus luteum secretes: Options: HCG, LH, FSH, progesterone'},
#   {'question_text': 'Which of the following does sperm NOT travel through?',
#    'options': ['ureter', 'urethra', 'vas deferens', 'epididymus'],
#    'answer': 'ureter',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-047',
#    'public_text': 'Which of the following does sperm NOT travel through? Options: ureter, urethra, vas deferens, epididymus'},
#   {'question_text': 'The placenta in humans is derived from the:',
#    'options': ['embryo only',
#     'uterus only',
#     'endometrium and embryo',
#     'none of the above'],
#    'answer': 'endometrium and embryo',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-048',
#    'public_text': 'The placenta in humans is derived from the: Options: embryo only, uterus only, endometrium and embryo, none of the above'},
#   {'question_text': 'The number of mature gametes resulting from meiosis in the female is:',
#    'options': ['1', '2', '3', '4'],
#    'answer': '1',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-049',
#    'public_text': 'The number of mature gametes resulting from meiosis in the female is: Options: 1, 2, 3, 4'},
#   {'question_text': 'Synapsis and crossing over of chromosomes occurs in which phases of meiosis?',
#    'options': ['Interphase', 'Prophase', 'Meterphase', 'Teleophase'],
#    'answer': 'Prophase',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-050',
#    'public_text': 'Synapsis and crossing over of chromosomes occurs in which phases of meiosis? Options: Interphase, Prophase, Meterphase, Teleophase'},
#   {'question_text': 'A layer of dead skin cells is found in the:',
#    'options': ['subcutaneous tissue',
#     'dermis',
#     'epidermis',
#     'no dead cells are in the skin'],
#    'answer': 'epidermis',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-051',
#    'public_text': 'A layer of dead skin cells is found in the: Options: subcutaneous tissue, dermis, epidermis, no dead cells are in the skin'},
#   {'question_text': 'Myelin sheaths are found:',
#    'options': ['surrounding tendons',
#     'covering the brain',
#     'covering muscles',
#     'around axons of neurons'],
#    'answer': 'around axons of neurons',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-052',
#    'public_text': 'Myelin sheaths are found: Options: surrounding tendons, covering the brain, covering muscles, around axons of neurons'},
#   {'question_text': 'Which of the following is an INCORRECT statement about the parasympathetic system?',
#    'options': ['It increases digestive action.',
#     'It is the fight or flight system.',
#     'slows breathing rate',
#     'establishes resting state'],
#    'answer': 'It is the fight or flight system.',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-053',
#    'public_text': 'Which of the following is an INCORRECT statement about the parasympathetic system? Options: It increases digestive action., It is the fight or flight system., slows breathing rate, establishes resting state'},
#   {'question_text': 'Which of the following is NOT a component of the human axial skeleton?',
#    'options': ['sternum', 'vertebral column', 'tarsals', 'skull'],
#    'answer': 'tarsals',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-054',
#    'public_text': 'Which of the following is NOT a component of the human axial skeleton? Options: sternum, vertebral column, tarsals, skull'},
#   {'question_text': 'Phalanges are found in the:',
#    'options': ['feet', 'skull', 'hip', 'chest'],
#    'answer': 'feet',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-055',
#    'public_text': 'Phalanges are found in the: Options: feet, skull, hip, chest'},
#   {'question_text': 'The phase of contraction of a muscle occurs when:',
#    'options': ['tropomyosin binds and releases actin',
#     'myosin binds and releases actin',
#     'actin binds and releases myosin',
#     'none of the above'],
#    'answer': 'myosin binds and releases actin',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-056',
#    'public_text': 'The phase of contraction of a muscle occurs when: Options: tropomyosin binds and releases actin, myosin binds and releases actin, actin binds and releases myosin, none of the above'},
#   {'question_text': 'Select the INCORRECT statement concerning the muscular system.',
#    'options': ['Bones contact other bones at joints.',
#     'Flexors decrease the angle of a joint.',
#     'Adductors move a limb away from the midline.',
#     'Tendons attach muscle to bone.'],
#    'answer': 'Adductors move a limb away from the midline.',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-057',
#    'public_text': 'Select the INCORRECT statement concerning the muscular system. Options: Bones contact other bones at joints., Flexors decrease the angle of a joint., Adductors move a limb away from the midline., Tendons attach muscle to bone.'},
#   {'question_text': 'Which type of muscle is a syncytium?',
#    'options': ['skeletal', 'cardiac', 'smooth', 'all of the above'],
#    'answer': 'skeletal',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-058',
#    'public_text': 'Which type of muscle is a syncytium? Options: skeletal, cardiac, smooth, all of the above'},
#   {'question_text': 'When the potential difference across a membrane of a neuron equals the threshold, what results?',
#    'options': ['movement of the membrane',
#     'action potential',
#     'relaxation',
#     'contraction'],
#    'answer': 'action potential',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-059',
#    'public_text': 'When the potential difference across a membrane of a neuron equals the threshold, what results? Options: movement of the membrane, action potential, relaxation, contraction'},
#   {'question_text': 'What ions determine the resting potential of a nerve?',
#    'options': ['sodium and calcium',
#     'calcium and copper',
#     'potassium and calcium',
#     'sodium and potassium'],
#    'answer': 'sodium and potassium',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-060',
#    'public_text': 'What ions determine the resting potential of a nerve? Options: sodium and calcium, calcium and copper, potassium and calcium, sodium and potassium'},
#   {'question_text': 'Which structure does NOT play a part in the motion of cells?',
#    'options': ['microvilli', 'cilia', 'flagella', 'pseudopodia'],
#    'answer': 'microvilli',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-061',
#    'public_text': 'Which structure does NOT play a part in the motion of cells? Options: microvilli, cilia, flagella, pseudopodia'},
#   {'question_text': 'Bacteriophage are:',
#    'options': ['bacteria',
#     'bacteria precursors',
#     'viruses',
#     'agents which cause the production of bacteria'],
#    'answer': 'viruses',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-062',
#    'public_text': 'Bacteriophage are: Options: bacteria, bacteria precursors, viruses, agents which cause the production of bacteria'},
#   {'question_text': 'Which of the following is NOT a mode of genetic exchange within a bacterial population?',
#    'options': ['conjugation', 'transduction', 'transformation', 'translation'],
#    'answer': 'translation',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-063',
#    'public_text': 'Which of the following is NOT a mode of genetic exchange within a bacterial population? Options: conjugation, transduction, transformation, translation'},
#   {'question_text': 'The blastula develops into the:',
#    'options': ['gastrula'],
#    'answer': 'gastrula',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-064',
#    'public_text': 'The blastula develops into the: Options: gastrula'},
#   {'question_text': 'Tissue differentiation begins at which stage?',
#    'options': ['zygote', 'morula', 'blastula', 'gastrula'],
#    'answer': 'gastrula',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-065',
#    'public_text': 'Tissue differentiation begins at which stage? Options: zygote, morula, blastula, gastrula'},
#   {'question_text': 'The nervous system develops from which germ layer?',
#    'options': ['ectoderm', 'mesoderm', 'endoderm', 'none of the above'],
#    'answer': 'ectoderm',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-066',
#    'public_text': 'The nervous system develops from which germ layer? Options: ectoderm, mesoderm, endoderm, none of the above'},
#   {'question_text': 'During inspiration, the diaphragm moves:',
#    'options': ['down by contraction',
#     'down by relaxation',
#     'up by contraction',
#     'up by relaxation'],
#    'answer': 'down by contraction',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-067',
#    'public_text': 'During inspiration, the diaphragm moves: Options: down by contraction, down by relaxation, up by contraction, up by relaxation'},
#   {'question_text': 'The valve between the right ventricle and the pulmonary artery is the:',
#    'options': ['mitral valve',
#     'semilunar valve',
#     'bicuspid valve',
#     'tricuspid valve'],
#    'answer': 'semilunar valve',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-068',
#    'public_text': 'The valve between the right ventricle and the pulmonary artery is the: Options: mitral valve, semilunar valve, bicuspid valve, tricuspid valve'},
#   {'question_text': 'Which of the following is NOT a function of the kidney?',
#    'options': ['excretion of urea',
#     'regulation of fluids and electrolytes',
#     'elimination of toxic substances',
#     'defecation'],
#    'answer': 'defecation',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-069',
#    'public_text': 'Which of the following is NOT a function of the kidney? Options: excretion of urea, regulation of fluids and electrolytes, elimination of toxic substances, defecation'},
#   {'question_text': 'When CO2 (carbon dioxide) is dissolved in water, it yields a solution that:',
#    'options': ['has acidic properties', 'has basic properties', 'is neutral'],
#    'answer': 'has acidic properties',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-070',
#    'public_text': 'When CO2 (carbon dioxide) is dissolved in water, it yields a solution that: Options: has acidic properties, has basic properties, is neutral'},
#   {'question_text': 'Digestion of carbohydrates begins where?',
#    'options': ['small intestines', 'colon', 'mouth', 'stomach'],
#    'answer': 'mouth',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-071',
#    'public_text': 'Digestion of carbohydrates begins where? Options: small intestines, colon, mouth, stomach'},
#   {'question_text': 'Digestion of PROTEINS begins in which of the following human organs?',
#    'options': ['small intestines', 'colon', 'mouth', 'stomach'],
#    'answer': 'stomach',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-072',
#    'public_text': 'Digestion of PROTEINS begins in which of the following human organs? Options: small intestines, colon, mouth, stomach'},
#   {'question_text': 'Bile has what function in digestion?',
#    'options': ['emulsify lipids',
#     'digest proteins',
#     'gluconeogenesis',
#     'digest carbohydrates'],
#    'answer': 'emulsify lipids',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-073',
#    'public_text': 'Bile has what function in digestion? Options: emulsify lipids, digest proteins, gluconeogenesis, digest carbohydrates'},
#   {'question_text': 'Of the following, which is a basic need of all living things?',
#    'options': ['oxygen gas', 'light', 'hydrogen gas', 'water'],
#    'answer': 'water',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-074',
#    'public_text': 'Of the following, which is a basic need of all living things? Options: oxygen gas, light, hydrogen gas, water'},
#   {'question_text': 'A botanist is most likely to study:',
#    'options': ['Monerans', 'Protistans', 'Fungi', 'Virions'],
#    'answer': 'Fungi',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-075',
#    'public_text': 'A botanist is most likely to study: Options: Monerans, Protistans, Fungi, Virions'},
#   {'question_text': 'A virus must do what to reproduce?',
#    'options': ['form a latent virus',
#     'undergo transformation',
#     'infect a cell',
#     'conjugate'],
#    'answer': 'infect a cell',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-076',
#    'public_text': 'A virus must do what to reproduce? Options: form a latent virus, undergo transformation, infect a cell, conjugate'},
#   {'question_text': 'The chromosomes of a eukaryotic cell are located in the:',
#    'options': ['mitochondria', 'nucleus', 'ribosome', 'endoplasma'],
#    'answer': 'nucleus',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-077',
#    'public_text': 'The chromosomes of a eukaryotic cell are located in the: Options: mitochondria, nucleus, ribosome, endoplasma'},
#   {'question_text': 'Which of the following is an example of symbiosis?',
#    'options': ['lichen', 'slime mold', 'amoeba', 'moss'],
#    'answer': 'lichen',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-078',
#    'public_text': 'Which of the following is an example of symbiosis? Options: lichen, slime mold, amoeba, moss'},
#   {'question_text': 'Oxygen enters the body of a grasshopper through:',
#    'options': ['gills', 'spinnerets', 'spiracles', 'book lungs'],
#    'answer': 'spiracles',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-079',
#    'public_text': 'Oxygen enters the body of a grasshopper through: Options: gills, spinnerets, spiracles, book lungs'},
#   {'question_text': 'A heart with a single atrium and single ventricle is a characteristic of adult:',
#    'options': ['amphibians', 'arthropods', 'birds', 'fish'],
#    'answer': 'fish',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-080',
#    'public_text': 'A heart with a single atrium and single ventricle is a characteristic of adult: Options: amphibians, arthropods, birds, fish'},
#   {'question_text': 'Name the four main excretory organs identified in man.',
#    'options': [],
#    'answer': 'skin, kidneys, lungs, intestinal tract',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-081',
#    'public_text': 'Name the four main excretory organs identified in man.'},
#   {'question_text': 'The physical appearance and properties of an organism which is the expression of the genetic makeup is called the:',
#    'options': ['phenotype', 'pangenesis', 'parental trait', 'genotype'],
#    'answer': 'phenotype',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-082',
#    'public_text': 'The physical appearance and properties of an organism which is the expression of the genetic makeup is called the: Options: phenotype, pangenesis, parental trait, genotype'},
#   {'question_text': 'How many nucleotides make up a codon?',
#    'options': [],
#    'answer': '3',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-083',
#    'public_text': 'How many nucleotides make up a codon?'},
#   {'question_text': 'The complex of sugar polymers and proteins which are patchily distributed on the plasma membranes of animal cells is called',
#    'options': ['cellulose', 'chitin', 'glyocalyx', 'cytoskeleton'],
#    'answer': 'glyocalyx',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-084',
#    'public_text': 'The complex of sugar polymers and proteins which are patchily distributed on the plasma membranes of animal cells is called Options: cellulose, chitin, glyocalyx, cytoskeleton'},
#   {'question_text': 'During cellular respiration, glucose is oxidized completely to what two compounds?',
#    'options': [],
#    'answer': 'CO2 (carbon dioxide) and H2O (water)',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-085',
#    'public_text': 'During cellular respiration, glucose is oxidized completely to what two compounds?'},
#   {'question_text': 'Organisms with cells containing two sets of parental chromosomes are called:',
#    'options': ['diploid', 'bisomal', 'haploid', 'autosomal'],
#    'answer': 'diploid',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-086',
#    'public_text': 'Organisms with cells containing two sets of parental chromosomes are called: Options: diploid, bisomal, haploid, autosomal'},
#   {'question_text': 'The type of gene interaction in which the effects of one gene override or mask the effects of other entirely different genes is called:',
#    'options': ['linkage', 'mutation', 'pleitropy', 'epistasis'],
#    'answer': 'epistasis',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-087',
#    'public_text': 'The type of gene interaction in which the effects of one gene override or mask the effects of other entirely different genes is called: Options: linkage, mutation, pleitropy, epistasis'},
#   {'question_text': 'For which of the following creatures is fat the greatest percentage of body weight?',
#    'options': ['termite', 'blue whale', 'zebra', 'female lion'],
#    'answer': 'blue whale',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-088',
#    'public_text': 'For which of the following creatures is fat the greatest percentage of body weight? Options: termite, blue whale, zebra, female lion'},
#   {'question_text': 'Which is false regarding freshwater fish?',
#    'options': ['their blood is hypertonic to their environment',
#     'they often actively take up salt',
#     'they excrete urine hypotonic to the blood',
#     'their gills actively excrete salts'],
#    'answer': 'their gills actively excrete salts',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-089',
#    'public_text': 'Which is false regarding freshwater fish? Options: their blood is hypertonic to their environment, they often actively take up salt, they excrete urine hypotonic to the blood, their gills actively excrete salts'},
#   {'question_text': 'Neutral fats, oils and waxes may be classified as:',
#    'options': ['lipids', 'carbohydrates', 'proteins', 'none of the above'],
#    'answer': 'lipids',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-090',
#    'public_text': 'Neutral fats, oils and waxes may be classified as: Options: lipids, carbohydrates, proteins, none of the above'},
#   {'question_text': 'Name three basic morphologies of bacteria.',
#    'options': [],
#    'answer': '(1) cocci (coccus), (2) bacilli (bacillus) or rod, (3) spirochetes or spirilla or spiral',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-091',
#    'public_text': 'Name three basic morphologies of bacteria.'},
#   {'question_text': 'What is the name of the 6 carbon monosaccharide that is the universal cellular fuel of plants and animals?',
#    'options': [],
#    'answer': 'glucose (dextrose)',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-092',
#    'public_text': 'What is the name of the 6 carbon monosaccharide that is the universal cellular fuel of plants and animals?'},
#   {'question_text': 'During which phase of the cell cycle are normal components of the cell synthesized and assembled?',
#    'options': ['the M phase', 'the G1 phase', 'the S phase', 'the G2 phase'],
#    'answer': 'the G1 phase',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-093',
#    'public_text': 'During which phase of the cell cycle are normal components of the cell synthesized and assembled? Options: the M phase, the G1 phase, the S phase, the G2 phase'},
#   {'question_text': 'Which of the following is NOT a characteristic shared by most of the members of the kingdom plantae?',
#    'options': ['they are multicellular',
#     'they are nonmotile',
#     'they possess bilateral symmetry',
#     'there is an alternation of haploid and diploid generations'],
#    'answer': 'they possess bilateral symmetry',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-094',
#    'public_text': 'Which of the following is NOT a characteristic shared by most of the members of the kingdom plantae? Options: they are multicellular, they are nonmotile, they possess bilateral symmetry, there is an alternation of haploid and diploid generations'},
#   {'question_text': 'If an individual has two dissimilar alleles for a trait, with regard to that trait he is said to be:',
#    'options': [],
#    'answer': 'heterozygous',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-095',
#    'public_text': 'If an individual has two dissimilar alleles for a trait, with regard to that trait he is said to be:'},
#   {'question_text': "How many chromosomes per cell does a Down's Syndrome (trisomy 21) victim have?",
#    'options': [],
#    'answer': '47',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-096',
#    'public_text': "How many chromosomes per cell does a Down's Syndrome (trisomy 21) victim have?"},
#   {'question_text': 'If a male who is heterozygous for an autosomal trait mates with a female who is also heterozygous for that trait, what percent of their offspring are likely to be heterozygous for this trait as well?',
#    'options': [],
#    'answer': '50%',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-097',
#    'public_text': 'If a male who is heterozygous for an autosomal trait mates with a female who is also heterozygous for that trait, what percent of their offspring are likely to be heterozygous for this trait as well?'}]}

# %%
import json

with open("biolset2.txt", "w") as f:
    json.dump(result.data, f, indent=4)

print("Structured data saved to biolset2.txt")
# Out:
# Structured data saved to biolset2.txt

# %%
result.data
# Out:
# {'questions': [{'question_text': 'The adult human of average age and size has approximately how many quarts of blood?',
#    'options': ['4', '6', '8', '10'],
#    'answer': '6',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-001',
#    'public_text': 'The adult human of average age and size has approximately how many quarts of blood? Options: 4, 6, 8, 10'},
#   {'question_text': 'Once the erythrocytes enter the blood in humans, it is estimated that they have an average lifetime of how many days?',
#    'options': ['10 days', '120 days', '200 days', '360 days'],
#    'answer': '120 days',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-002',
#    'public_text': 'Once the erythrocytes enter the blood in humans, it is estimated that they have an average lifetime of how many days? Options: 10 days, 120 days, 200 days, 360 days'},
#   {'question_text': 'Which mechanisms are important in the death of erythrocytes in human blood?',
#    'options': ['phagocytosis',
#     'hemolysis',
#     'mechanical damage',
#     'all of the above'],
#    'answer': 'all of the above',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-003',
#    'public_text': 'Which mechanisms are important in the death of erythrocytes in human blood? Options: phagocytosis, hemolysis, mechanical damage, all of the above'},
#   {'question_text': 'Surplus red blood cells, needed to meet an emergency, are MAINLY stored in what organ of the human body?',
#    'options': ['pancreas', 'spleen', 'liver', 'kidneys'],
#    'answer': 'spleen',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-004',
#    'public_text': 'Surplus red blood cells, needed to meet an emergency, are MAINLY stored in what organ of the human body? Options: pancreas, spleen, liver, kidneys'},
#   {'question_text': 'When a human donor gives a pint of blood, how many weeks does it usually take for the body reserve of red corpuscles to be replaced?',
#    'options': ['1 week', '3 weeks', '7 weeks', '21 weeks'],
#    'answer': '7 weeks',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-005',
#    'public_text': 'When a human donor gives a pint of blood, how many weeks does it usually take for the body reserve of red corpuscles to be replaced? Options: 1 week, 3 weeks, 7 weeks, 21 weeks'},
#   {'question_text': 'There are three substances found in human blood which carry oxygen and which begin with the letter "H". Name two of these substances.',
#    'options': [],
#    'answer': 'Hemoglobin, Hemocyanin, Hemerythrin (any two)',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-006',
#    'public_text': 'There are three substances found in human blood which carry oxygen and which begin with the letter "H". Name two of these substances.'},
#   {'question_text': 'The several types of white blood cells are sometimes collectively referred to as:',
#    'options': [],
#    'answer': '',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-007',
#    'public_text': 'The several types of white blood cells are sometimes collectively referred to as:'},
#   {'question_text': 'The condition in which there is a DECREASE in the number of white blood cells in humans is known as:',
#    'options': ['leukocytosis', 'leukopenia', 'leukemia', 'leukohyperia'],
#    'answer': 'leukopenia',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-008',
#    'public_text': 'The condition in which there is a DECREASE in the number of white blood cells in humans is known as: Options: leukocytosis, leukopenia, leukemia, leukohyperia'},
#   {'question_text': 'The smallest of the FORMED elements of the blood are the:',
#    'options': ['white cells', 'red cells', 'platelets', 'erythrocytes'],
#    'answer': 'platelets',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-009',
#    'public_text': 'The smallest of the FORMED elements of the blood are the: Options: white cells, red cells, platelets, erythrocytes'},
#   {'question_text': 'Which of the following statements concerning platelets is INCORRECT?',
#    'options': ['contain DNA',
#     'are roughly disk‑shaped',
#     'have little ability to synthesize proteins',
#     'are between 1/2 and 1/3 the diameter of the red cell'],
#    'answer': 'contain DNA',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-010',
#    'public_text': 'Which of the following statements concerning platelets is INCORRECT? Options: contain DNA, are roughly disk‑shaped, have little ability to synthesize proteins, are between 1/2 and 1/3 the diameter of the red cell'},
#   {'question_text': 'What is the primary function of the platelets in human blood?',
#    'options': [],
#    'answer': 'clotting or blocking leaks from blood vessels',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-011',
#    'public_text': 'What is the primary function of the platelets in human blood?'},
#   {'question_text': 'When a wound occurs in humans, the platelets in the blood activate a substance which starts the clotting process. The substance which starts the clotting is:',
#    'options': ['adenosine', 'histamine', 'lecithin', 'thrombin'],
#    'answer': 'thrombin',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-012',
#    'public_text': 'When a wound occurs in humans, the platelets in the blood activate a substance which starts the clotting process. The substance which starts the clotting is: Options: adenosine, histamine, lecithin, thrombin'},
#   {'question_text': 'When looking at the cross section of the human tibia, one finds the RED marrow in the:',
#    'options': ['medullary cavity',
#     'cancellous bone',
#     'periosteum',
#     'epiphysis'],
#    'answer': 'medullary cavity',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-013',
#    'public_text': 'When looking at the cross section of the human tibia, one finds the RED marrow in the: Options: medullary cavity, cancellous bone, periosteum, epiphysis'},
#   {'question_text': 'Lengthening of long bones in humans occurs in a particular area of the bone. This area is called the:',
#    'options': ['medullary canal',
#     'cancellous bone',
#     'periosteum',
#     'epiphysis'],
#    'answer': 'epiphysis',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-014',
#    'public_text': 'Lengthening of long bones in humans occurs in a particular area of the bone. This area is called the: Options: medullary canal, cancellous bone, periosteum, epiphysis'},
#   {'question_text': 'The part of the human brain which is an important relay station for the sensory impulses and also is the origin of many of the involuntary acts of the eye such as the narrowing of the pupil in bright light is the:',
#    'options': ['hypothalamus', 'midbrain', 'corpus callosum', 'cerebellum'],
#    'answer': 'midbrain',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-015',
#    'public_text': 'The part of the human brain which is an important relay station for the sensory impulses and also is the origin of many of the involuntary acts of the eye such as the narrowing of the pupil in bright light is the: Options: hypothalamus, midbrain, corpus callosum, cerebellum'},
#   {'question_text': "In the human brain, body temperature, metabolism, heart rate, sexual development, sleep and the body's use of fat and water are influenced by this region of the brain. This region of the brain is the:",
#    'options': ['hypothalamus', 'midbrain', 'corpus callosum', 'cerebellum'],
#    'answer': 'hypothalamus',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-016',
#    'public_text': "In the human brain, body temperature, metabolism, heart rate, sexual development, sleep and the body's use of fat and water are influenced by this region of the brain. This region of the brain is the: Options: hypothalamus, midbrain, corpus callosum, cerebellum"},
#   {'question_text': 'In which cerebral lobes is the speech center located?',
#    'options': ['frontal', 'parietal', 'temporal', 'occipital'],
#    'answer': 'frontal',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-017',
#    'public_text': 'In which cerebral lobes is the speech center located? Options: frontal, parietal, temporal, occipital'},
#   {'question_text': 'In most axons, the myelin sheath is interrupted at intervals of about 1 millimeter or more. These interruptions are called the:',
#    'options': ['glial', 'nodes of Ranvier', 'collaterals', 'nodes of Babinet'],
#    'answer': 'nodes of Ranvier',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-018',
#    'public_text': 'In most axons, the myelin sheath is interrupted at intervals of about 1 millimeter or more. These interruptions are called the: Options: glial, nodes of Ranvier, collaterals, nodes of Babinet'},
#   {'question_text': 'Mosses and liverworts comprise this subdivision of plants. Name this plant subdivision.',
#    'options': [],
#    'answer': 'Bryophytes or Bryophyta',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-019',
#    'public_text': 'Mosses and liverworts comprise this subdivision of plants. Name this plant subdivision.'},
#   {'question_text': 'This disease, caused by infection with the gram‑negative Yersinia pestis, is transmitted by fleas from rats to humans. What is the more common name for this disease?',
#    'options': [],
#    'answer': 'Bubonic Plague or Black Death',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-020',
#    'public_text': 'This disease, caused by infection with the gram‑negative Yersinia pestis, is transmitted by fleas from rats to humans. What is the more common name for this disease?'},
#   {'question_text': 'In the mammalian body, this element plays many important roles: integrity and permeability of cell membranes, regulation of nerve and muscle excitability, muscle contraction, cardiac rhythmicity, blood coagulation, and is the most important element of bone salt. Name this element.',
#    'options': [],
#    'answer': 'Calcium',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-021',
#    'public_text': 'In the mammalian body, this element plays many important roles: integrity and permeability of cell membranes, regulation of nerve and muscle excitability, muscle contraction, cardiac rhythmicity, blood coagulation, and is the most important element of bone salt. Name this element.'},
#   {'question_text': 'What eight‑letter name starting with the letter "O" is given to that branch of medical science concerned with the study of tumors?',
#    'options': [],
#    'answer': 'Oncology',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-022',
#    'public_text': 'What eight‑letter name starting with the letter "O" is given to that branch of medical science concerned with the study of tumors?'},
#   {'question_text': 'In the more highly developed animals, such as humans, this gas is used to regulate the activity of the heart, blood vessels, and the respiratory system. Working muscles produce a large amount of this substance. Narcosis due to this gas causes mental disturbances. Name this gas.',
#    'options': [],
#    'answer': 'Carbon Dioxide or CO2',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-023',
#    'public_text': 'In the more highly developed animals, such as humans, this gas is used to regulate the activity of the heart, blood vessels, and the respiratory system. Working muscles produce a large amount of this substance. Narcosis due to this gas causes mental disturbances. Name this gas.'},
#   {'question_text': 'Cariology is the study of the:',
#    'options': ['human heart', 'tooth decay', 'kidneys', 'liver'],
#    'answer': 'tooth decay',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-024',
#    'public_text': 'Cariology is the study of the: Options: human heart, tooth decay, kidneys, liver'},
#   {'question_text': 'The larval form of butterflies and moths is more commonly known as what?',
#    'options': [],
#    'answer': 'caterpillar',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-025',
#    'public_text': 'The larval form of butterflies and moths is more commonly known as what?'},
#   {'question_text': 'Name the sac‑like, blind pouch of the large intestine, situated below the level of the junction of the small intestine into the side of the large intestine. At the lower portion of this pouch one finds the appendix.',
#    'options': [],
#    'answer': 'Cecum or Caecum',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-026',
#    'public_text': 'Name the sac‑like, blind pouch of the large intestine, situated below the level of the junction of the small intestine into the side of the large intestine. At the lower portion of this pouch one finds the appendix.'},
#   {'question_text': 'During the final stage of cell division, the mitotic apparatus disappears, the chromosomes become attenuated, the centrioles duplicate and split, the nuclear membrane becomes reconstituted and the nucleolus reappears. This phase is known as:',
#    'options': ['prophase', 'metaphase', 'anaphase', 'telophase'],
#    'answer': 'telophase',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-027',
#    'public_text': 'During the final stage of cell division, the mitotic apparatus disappears, the chromosomes become attenuated, the centrioles duplicate and split, the nuclear membrane becomes reconstituted and the nucleolus reappears. This phase is known as: Options: prophase, metaphase, anaphase, telophase'},
#   {'question_text': 'All cells of an organism find their lineage from a single fertilized cell. This single fertilized cell is called what?',
#    'options': [],
#    'answer': 'zygot',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-028',
#    'public_text': 'All cells of an organism find their lineage from a single fertilized cell. This single fertilized cell is called what?'},
#   {'question_text': 'Name the clear watery liquid that surrounds the brain and spinal cord and fills the four cavities or ventricles of the brain.',
#    'options': [],
#    'answer': 'cerebrospinal fluid',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-029',
#    'public_text': 'Name the clear watery liquid that surrounds the brain and spinal cord and fills the four cavities or ventricles of the brain.'},
#   {'question_text': 'The order of insects which includes beetles is known as:',
#    'options': ['Coleoptera', 'Orthoptera', 'Hymenoptera', 'Diptera'],
#    'answer': 'Coleoptera',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-030',
#    'public_text': 'The order of insects which includes beetles is known as: Options: Coleoptera, Orthoptera, Hymenoptera, Diptera'},
#   {'question_text': 'This major protein component of connective tissue in mammals comprises most of the organic matter of skin, tendons, bones, and teeth, and occurs as fibrous inclusions in most other body structures.',
#    'options': ['elastin', 'collagen', 'fatty acids', 'keratin'],
#    'answer': 'collagen',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-031',
#    'public_text': 'This major protein component of connective tissue in mammals comprises most of the organic matter of skin, tendons, bones, and teeth, and occurs as fibrous inclusions in most other body structures. Options: elastin, collagen, fatty acids, keratin'},
#   {'question_text': "Sickle cell anemia and Huntington's chorea are both:",
#    'options': ['virus‑related diseases',
#     'bacteria‑related diseases',
#     'congenital disorders',
#     'none of the above'],
#    'answer': 'congenital disorders',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-032',
#    'public_text': "Sickle cell anemia and Huntington's chorea are both: Options: virus‑related diseases, bacteria‑related diseases, congenital disorders, none of the above"},
#   {'question_text': 'In most species of Paramecium there are how many contractile vacuoles?',
#    'options': ['one', 'two', 'three', 'four'],
#    'answer': 'two',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-033',
#    'public_text': 'In most species of Paramecium there are how many contractile vacuoles? Options: one, two, three, four'},
#   {'question_text': 'Name the outer portion of a stem or root, bounded externally by the epidermis, and internally by the cells of the pericycle.',
#    'options': [],
#    'answer': 'Cortex',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-034',
#    'public_text': 'Name the outer portion of a stem or root, bounded externally by the epidermis, and internally by the cells of the pericycle.'},
#   {'question_text': 'Costal cartilage:',
#    'options': ['attach the ribs to the sternum',
#     'cover the ends of the femur',
#     'is found in the pinna of the ear',
#     'forms the intervertebral disks of the backbone'],
#    'answer': 'attach the ribs to the sternum',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-035',
#    'public_text': 'Costal cartilage: Options: attach the ribs to the sternum, cover the ends of the femur, is found in the pinna of the ear, forms the intervertebral disks of the backbone'},
#   {'question_text': 'From which grandparent or grandparents did you inherit your mitochondria?',
#    'options': ["mother's parents",
#     'paternal grandfather',
#     'grand mothers',
#     'maternal grandmother'],
#    'answer': 'maternal grandmother',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-036',
#    'public_text': "From which grandparent or grandparents did you inherit your mitochondria? Options: mother's parents, paternal grandfather, grand mothers, maternal grandmother"},
#   {'question_text': 'Which of the following are NOT part of a neuron?',
#    'options': ['synapse', 'axon', 'Nissl bodies', 'dendrite'],
#    'answer': 'synapse',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-037',
#    'public_text': 'Which of the following are NOT part of a neuron? Options: synapse, axon, Nissl bodies, dendrite'},
#   {'question_text': 'The resting potential of a neuron is dependent on what two ions?',
#    'options': ['lead and calcium ions',
#     'calcium and phosphate ions',
#     'sodium and potassium ions',
#     'potassium and phosphate ions'],
#    'answer': 'sodium and potassium ions',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-038',
#    'public_text': 'The resting potential of a neuron is dependent on what two ions? Options: lead and calcium ions, calcium and phosphate ions, sodium and potassium ions, potassium and phosphate ions'},
#   {'question_text': 'Which of the following is NOT a type of neuron?',
#    'options': ['sensory', 'motor', 'association', 'stimulatory'],
#    'answer': 'stimulatory',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-039',
#    'public_text': 'Which of the following is NOT a type of neuron? Options: sensory, motor, association, stimulatory'},
#   {'question_text': 'Melatonin is produced by the:',
#    'options': ['skin'],
#    'answer': '',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-040',
#    'public_text': 'Melatonin is produced by the: Options: skin'},
#   {'question_text': 'Which of the following statements is TRUE of insulin?',
#    'options': ['secreted by the pancreas',
#     'a protein',
#     'involved in the metabolism of glucose',
#     'all of the above'],
#    'answer': 'all of the above',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-041',
#    'public_text': 'Which of the following statements is TRUE of insulin? Options: secreted by the pancreas, a protein, involved in the metabolism of glucose, all of the above'},
#   {'question_text': 'Select the hormone INCORRECTLY paired with its target.',
#    'options': ['TSH - thyroid gland',
#     'ACTH - anterior pituitary',
#     'LH - ovary or testis',
#     'MSH - melanocytes'],
#    'answer': 'MSH - melanocytes',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-042',
#    'public_text': 'Select the hormone INCORRECTLY paired with its target. Options: TSH - thyroid gland, ACTH - anterior pituitary, LH - ovary or testis, MSH - melanocytes'},
#   {'question_text': 'Which of the following tissues secrete hormones?',
#    'options': ['pancreas',
#     'ovaries',
#     'gastro-intestinal tract',
#     'all of the above'],
#    'answer': 'all of the above',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-043',
#    'public_text': 'Which of the following tissues secrete hormones? Options: pancreas, ovaries, gastro-intestinal tract, all of the above'},
#   {'question_text': 'Which of the following structures is directly attached to the ovary?',
#    'options': ['oviduct', 'uterus', 'suspensory ligaments', 'vagina'],
#    'answer': 'suspensory ligaments',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-044',
#    'public_text': 'Which of the following structures is directly attached to the ovary? Options: oviduct, uterus, suspensory ligaments, vagina'},
#   {'question_text': 'Fertilization of the ovum by the sperm usually occurs in the:',
#    'options': ['oviduct', 'vagina', 'uterus', 'ovary'],
#    'answer': 'oviduct',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-045',
#    'public_text': 'Fertilization of the ovum by the sperm usually occurs in the: Options: oviduct, vagina, uterus, ovary'},
#   {'question_text': 'The corpeus luteum secretes:',
#    'options': ['HCG', 'LH', 'FSH', 'progesterone'],
#    'answer': 'progesterone',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-046',
#    'public_text': 'The corpeus luteum secretes: Options: HCG, LH, FSH, progesterone'},
#   {'question_text': 'Which of the following does sperm NOT travel through?',
#    'options': ['ureter', 'urethra', 'vas deferens', 'epididymus'],
#    'answer': 'ureter',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-047',
#    'public_text': 'Which of the following does sperm NOT travel through? Options: ureter, urethra, vas deferens, epididymus'},
#   {'question_text': 'The placenta in humans is derived from the:',
#    'options': ['embryo only',
#     'uterus only',
#     'endometrium and embryo',
#     'none of the above'],
#    'answer': 'endometrium and embryo',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-048',
#    'public_text': 'The placenta in humans is derived from the: Options: embryo only, uterus only, endometrium and embryo, none of the above'},
#   {'question_text': 'The number of mature gametes resulting from meiosis in the female is:',
#    'options': ['1', '2', '3', '4'],
#    'answer': '1',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-049',
#    'public_text': 'The number of mature gametes resulting from meiosis in the female is: Options: 1, 2, 3, 4'},
#   {'question_text': 'Synapsis and crossing over of chromosomes occurs in which phases of meiosis?',
#    'options': ['Interphase', 'Prophase', 'Meterphase', 'Teleophase'],
#    'answer': 'Prophase',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-050',
#    'public_text': 'Synapsis and crossing over of chromosomes occurs in which phases of meiosis? Options: Interphase, Prophase, Meterphase, Teleophase'},
#   {'question_text': 'A layer of dead skin cells is found in the:',
#    'options': ['subcutaneous tissue',
#     'dermis',
#     'epidermis',
#     'no dead cells are in the skin'],
#    'answer': 'epidermis',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-051',
#    'public_text': 'A layer of dead skin cells is found in the: Options: subcutaneous tissue, dermis, epidermis, no dead cells are in the skin'},
#   {'question_text': 'Myelin sheaths are found:',
#    'options': ['surrounding tendons',
#     'covering the brain',
#     'covering muscles',
#     'around axons of neurons'],
#    'answer': 'around axons of neurons',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-052',
#    'public_text': 'Myelin sheaths are found: Options: surrounding tendons, covering the brain, covering muscles, around axons of neurons'},
#   {'question_text': 'Which of the following is an INCORRECT statement about the parasympathetic system?',
#    'options': ['It increases digestive action.',
#     'It is the fight or flight system.',
#     'slows breathing rate',
#     'establishes resting state'],
#    'answer': 'It is the fight or flight system.',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-053',
#    'public_text': 'Which of the following is an INCORRECT statement about the parasympathetic system? Options: It increases digestive action., It is the fight or flight system., slows breathing rate, establishes resting state'},
#   {'question_text': 'Which of the following is NOT a component of the human axial skeleton?',
#    'options': ['sternum', 'vertebral column', 'tarsals', 'skull'],
#    'answer': 'tarsals',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-054',
#    'public_text': 'Which of the following is NOT a component of the human axial skeleton? Options: sternum, vertebral column, tarsals, skull'},
#   {'question_text': 'Phalanges are found in the:',
#    'options': ['feet', 'skull', 'hip', 'chest'],
#    'answer': 'feet',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-055',
#    'public_text': 'Phalanges are found in the: Options: feet, skull, hip, chest'},
#   {'question_text': 'The phase of contraction of a muscle occurs when:',
#    'options': ['tropomyosin binds and releases actin',
#     'myosin binds and releases actin',
#     'actin binds and releases myosin',
#     'none of the above'],
#    'answer': 'myosin binds and releases actin',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-056',
#    'public_text': 'The phase of contraction of a muscle occurs when: Options: tropomyosin binds and releases actin, myosin binds and releases actin, actin binds and releases myosin, none of the above'},
#   {'question_text': 'Select the INCORRECT statement concerning the muscular system.',
#    'options': ['Bones contact other bones at joints.',
#     'Flexors decrease the angle of a joint.',
#     'Adductors move a limb away from the midline.',
#     'Tendons attach muscle to bone.'],
#    'answer': 'Adductors move a limb away from the midline.',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-057',
#    'public_text': 'Select the INCORRECT statement concerning the muscular system. Options: Bones contact other bones at joints., Flexors decrease the angle of a joint., Adductors move a limb away from the midline., Tendons attach muscle to bone.'},
#   {'question_text': 'Which type of muscle is a syncytium?',
#    'options': ['skeletal', 'cardiac', 'smooth', 'all of the above'],
#    'answer': 'skeletal',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-058',
#    'public_text': 'Which type of muscle is a syncytium? Options: skeletal, cardiac, smooth, all of the above'},
#   {'question_text': 'When the potential difference across a membrane of a neuron equals the threshold, what results?',
#    'options': ['movement of the membrane',
#     'action potential',
#     'relaxation',
#     'contraction'],
#    'answer': 'action potential',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-059',
#    'public_text': 'When the potential difference across a membrane of a neuron equals the threshold, what results? Options: movement of the membrane, action potential, relaxation, contraction'},
#   {'question_text': 'What ions determine the resting potential of a nerve?',
#    'options': ['sodium and calcium',
#     'calcium and copper',
#     'potassium and calcium',
#     'sodium and potassium'],
#    'answer': 'sodium and potassium',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-060',
#    'public_text': 'What ions determine the resting potential of a nerve? Options: sodium and calcium, calcium and copper, potassium and calcium, sodium and potassium'},
#   {'question_text': 'Which structure does NOT play a part in the motion of cells?',
#    'options': ['microvilli', 'cilia', 'flagella', 'pseudopodia'],
#    'answer': 'microvilli',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-061',
#    'public_text': 'Which structure does NOT play a part in the motion of cells? Options: microvilli, cilia, flagella, pseudopodia'},
#   {'question_text': 'Bacteriophage are:',
#    'options': ['bacteria',
#     'bacteria precursors',
#     'viruses',
#     'agents which cause the production of bacteria'],
#    'answer': 'viruses',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-062',
#    'public_text': 'Bacteriophage are: Options: bacteria, bacteria precursors, viruses, agents which cause the production of bacteria'},
#   {'question_text': 'Which of the following is NOT a mode of genetic exchange within a bacterial population?',
#    'options': ['conjugation', 'transduction', 'transformation', 'translation'],
#    'answer': 'translation',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-063',
#    'public_text': 'Which of the following is NOT a mode of genetic exchange within a bacterial population? Options: conjugation, transduction, transformation, translation'},
#   {'question_text': 'The blastula develops into the:',
#    'options': ['gastrula'],
#    'answer': 'gastrula',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-064',
#    'public_text': 'The blastula develops into the: Options: gastrula'},
#   {'question_text': 'Tissue differentiation begins at which stage?',
#    'options': ['zygote', 'morula', 'blastula', 'gastrula'],
#    'answer': 'gastrula',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-065',
#    'public_text': 'Tissue differentiation begins at which stage? Options: zygote, morula, blastula, gastrula'},
#   {'question_text': 'The nervous system develops from which germ layer?',
#    'options': ['ectoderm', 'mesoderm', 'endoderm', 'none of the above'],
#    'answer': 'ectoderm',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-066',
#    'public_text': 'The nervous system develops from which germ layer? Options: ectoderm, mesoderm, endoderm, none of the above'},
#   {'question_text': 'During inspiration, the diaphragm moves:',
#    'options': ['down by contraction',
#     'down by relaxation',
#     'up by contraction',
#     'up by relaxation'],
#    'answer': 'down by contraction',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-067',
#    'public_text': 'During inspiration, the diaphragm moves: Options: down by contraction, down by relaxation, up by contraction, up by relaxation'},
#   {'question_text': 'The valve between the right ventricle and the pulmonary artery is the:',
#    'options': ['mitral valve',
#     'semilunar valve',
#     'bicuspid valve',
#     'tricuspid valve'],
#    'answer': 'semilunar valve',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-068',
#    'public_text': 'The valve between the right ventricle and the pulmonary artery is the: Options: mitral valve, semilunar valve, bicuspid valve, tricuspid valve'},
#   {'question_text': 'Which of the following is NOT a function of the kidney?',
#    'options': ['excretion of urea',
#     'regulation of fluids and electrolytes',
#     'elimination of toxic substances',
#     'defecation'],
#    'answer': 'defecation',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-069',
#    'public_text': 'Which of the following is NOT a function of the kidney? Options: excretion of urea, regulation of fluids and electrolytes, elimination of toxic substances, defecation'},
#   {'question_text': 'When CO2 is dissolved in water, it yields a solution that:',
#    'options': ['has acidic properties', 'has basic properties', 'is neutral'],
#    'answer': 'has acidic properties',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-070',
#    'public_text': 'When CO2 is dissolved in water, it yields a solution that: Options: has acidic properties, has basic properties, is neutral'},
#   {'question_text': 'Digestion of carbohydrates begins where?',
#    'options': ['small intestines', 'colon', 'mouth', 'stomach'],
#    'answer': 'mouth',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-071',
#    'public_text': 'Digestion of carbohydrates begins where? Options: small intestines, colon, mouth, stomach'},
#   {'question_text': 'Digestion of proteins begins in which of the following human organs?',
#    'options': ['small intestines', 'colon', 'mouth', 'stomach'],
#    'answer': 'stomach',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-072',
#    'public_text': 'Digestion of proteins begins in which of the following human organs? Options: small intestines, colon, mouth, stomach'},
#   {'question_text': 'Bile has what function in digestion?',
#    'options': ['emulsify lipids',
#     'digest proteins',
#     'gluconeogenesis',
#     'digest carbohydrates'],
#    'answer': 'emulsify lipids',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-073',
#    'public_text': 'Bile has what function in digestion? Options: emulsify lipids, digest proteins, gluconeogenesis, digest carbohydrates'},
#   {'question_text': 'Of the following, which is a basic need of all living things?',
#    'options': ['oxygen gas', 'light', 'hydrogen gas', 'water'],
#    'answer': 'water',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-074',
#    'public_text': 'Of the following, which is a basic need of all living things? Options: oxygen gas, light, hydrogen gas, water'},
#   {'question_text': 'A botanist is most likely to study:',
#    'options': ['Monerans', 'Protistans', 'Fungi', 'Virions'],
#    'answer': 'Fungi',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-075',
#    'public_text': 'A botanist is most likely to study: Options: Monerans, Protistans, Fungi, Virions'},
#   {'question_text': 'A virus must do what to reproduce?',
#    'options': ['form a latent virus',
#     'undergo transformation',
#     'infect a cell',
#     'conjugate'],
#    'answer': 'infect a cell',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-076',
#    'public_text': 'A virus must do what to reproduce? Options: form a latent virus, undergo transformation, infect a cell, conjugate'},
#   {'question_text': 'The chromosomes of a eukaryotic cell are located in the:',
#    'options': ['mitochondria', 'nucleus', 'ribosome', 'endoplasma'],
#    'answer': 'nucleus',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-077',
#    'public_text': 'The chromosomes of a eukaryotic cell are located in the: Options: mitochondria, nucleus, ribosome, endoplasma'},
#   {'question_text': 'Which of the following is an example of symbiosis?',
#    'options': ['lichen', 'slime mold', 'amoeba', 'moss'],
#    'answer': 'lichen',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-078',
#    'public_text': 'Which of the following is an example of symbiosis? Options: lichen, slime mold, amoeba, moss'},
#   {'question_text': 'Oxygen enters the body of a grasshopper through:',
#    'options': ['gills', 'spinnerets', 'spiracles', 'book lungs'],
#    'answer': 'spiracles',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-079',
#    'public_text': 'Oxygen enters the body of a grasshopper through: Options: gills, spinnerets, spiracles, book lungs'},
#   {'question_text': 'A heart with a single atrium and single ventricle is a characteristic of adult:',
#    'options': ['amphibians', 'arthropods', 'birds', 'fish'],
#    'answer': 'fish',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-080',
#    'public_text': 'A heart with a single atrium and single ventricle is a characteristic of adult: Options: amphibians, arthropods, birds, fish'},
#   {'question_text': 'Name the four main excretory organs identified in man.',
#    'options': [],
#    'answer': 'SKIN, KIDNEYS, LUNGS, INTESTINAL TRACT',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-081',
#    'public_text': 'Name the four main excretory organs identified in man.'},
#   {'question_text': 'The physical appearance and properties of an organism which is the expression of the genetic makeup is called the:',
#    'options': ['phenotype', 'pangenesis', 'parental trait', 'genotype'],
#    'answer': 'phenotype',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-082',
#    'public_text': 'The physical appearance and properties of an organism which is the expression of the genetic makeup is called the: Options: phenotype, pangenesis, parental trait, genotype'},
#   {'question_text': 'How many nucleotides make up a codon?',
#    'options': [],
#    'answer': '3',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-083',
#    'public_text': 'How many nucleotides make up a codon?'},
#   {'question_text': 'The complex of sugar polymers and proteins which are patchily distributed on the plasma membranes of animal cells is called:',
#    'options': ['cellulose', 'chitin', 'glyocalyx', 'cytoskeleton'],
#    'answer': 'glyocalyx',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-084',
#    'public_text': 'The complex of sugar polymers and proteins which are patchily distributed on the plasma membranes of animal cells is called: Options: cellulose, chitin, glyocalyx, cytoskeleton'},
#   {'question_text': 'During cellular respiration, glucose is oxidized completely to what two compounds?',
#    'options': [],
#    'answer': 'CO2 (carbon dioxide) and H2O (water)',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-085',
#    'public_text': 'During cellular respiration, glucose is oxidized completely to what two compounds?'},
#   {'question_text': 'Organisms with cells containing two sets of parental chromosomes are called:',
#    'options': ['diploid', 'bisomal', 'haploid', 'autosomal'],
#    'answer': 'diploid',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-086',
#    'public_text': 'Organisms with cells containing two sets of parental chromosomes are called: Options: diploid, bisomal, haploid, autosomal'},
#   {'question_text': 'The type of gene interaction in which the effects of one gene override or mask the effects of other entirely different genes is called:',
#    'options': ['linkage', 'mutation', 'pleitropy', 'epistasis'],
#    'answer': 'epistasis',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-087',
#    'public_text': 'The type of gene interaction in which the effects of one gene override or mask the effects of other entirely different genes is called: Options: linkage, mutation, pleitropy, epistasis'},
#   {'question_text': 'For which of the following creatures is fat the greatest percentage of body weight?',
#    'options': ['termite', 'blue whale', 'zebra', 'female lion'],
#    'answer': 'blue whale',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-088',
#    'public_text': 'For which of the following creatures is fat the greatest percentage of body weight? Options: termite, blue whale, zebra, female lion'},
#   {'question_text': 'Which is false regarding freshwater fish?',
#    'options': ['their blood is hypertonic to their environment',
#     'they often actively take up salt',
#     'they excrete urine hypotonic to the blood',
#     'their gills actively excrete salts'],
#    'answer': 'their gills actively excrete salts',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-089',
#    'public_text': 'Which is false regarding freshwater fish? Options: their blood is hypertonic to their environment, they often actively take up salt, they excrete urine hypotonic to the blood, their gills actively excrete salts'},
#   {'question_text': 'Neutral fats, oils and waxes may be classified as:',
#    'options': ['lipids', 'carbohydrates', 'proteins', 'none of the above'],
#    'answer': 'lipids',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-090',
#    'public_text': 'Neutral fats, oils and waxes may be classified as: Options: lipids, carbohydrates, proteins, none of the above'},
#   {'question_text': 'Name three basic morphologies of bacteria.',
#    'options': [],
#    'answer': 'COCCI (COCCUS), BACILLI (BACILLUS) or ROD, SPIROCHETES or SPIRILLA or SPIRAL',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-091',
#    'public_text': 'Name three basic morphologies of bacteria.'},
#   {'question_text': 'What is the name of the 6 carbon monosaccharide that is the universal cellular fuel of plants and animals?',
#    'options': [],
#    'answer': 'Glucose (dextrose)',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-092',
#    'public_text': 'What is the name of the 6 carbon monosaccharide that is the universal cellular fuel of plants and animals?'},
#   {'question_text': 'During which phase of the cell cycle are normal components of the cell synthesized and assembled?',
#    'options': ['the M phase', 'the G1 phase', 'the S phase', 'the G2 phase'],
#    'answer': 'the G1 phase',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-093',
#    'public_text': 'During which phase of the cell cycle are normal components of the cell synthesized and assembled? Options: the M phase, the G1 phase, the S phase, the G2 phase'},
#   {'question_text': 'Which of the following is NOT a characteristic shared by most of the members of the kingdom plantae?',
#    'options': ['they are multicellular',
#     'they are nonmotile',
#     'they possess bilateral symmetry',
#     'there is an alternation of haploid and diploid generations'],
#    'answer': 'they possess bilateral symmetry',
#    'department': 'Biology',
#    'question_type': 'MCQ',
#    'question_id': 'BIO-094',
#    'public_text': 'Which of the following is NOT a characteristic shared by most of the members of the kingdom plantae? Options: they are multicellular, they are nonmotile, they possess bilateral symmetry, there is an alternation of haploid and diploid generations'},
#   {'question_text': 'If an individual has two dissimilar alleles for a trait, with regard to that trait he is said to be:',
#    'options': [],
#    'answer': 'heterozygous',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-095',
#    'public_text': 'If an individual has two dissimilar alleles for a trait, with regard to that trait he is said to be:'},
#   {'question_text': "How many chromosomes per cell does a Down's Syndrome (trisomy 21) victim have?",
#    'options': [],
#    'answer': '47',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-096',
#    'public_text': "How many chromosomes per cell does a Down's Syndrome (trisomy 21) victim have?"},
#   {'question_text': 'If a male who is heterozygous for an autosomal trait mates with a female who is also heterozygous for that trait, what percent of their offspring are likely to be heterozygous for this trait as well?',
#    'options': [],
#    'answer': '50%',
#    'department': 'Biology',
#    'question_type': 'Short Answer',
#    'question_id': 'BIO-097',
#    'public_text': 'If a male who is heterozygous for an autosomal trait mates with a female who is also heterozygous for that trait, what percent of their offspring are likely to be heterozygous for this trait as well?'}]}

# %%
from pymongo import MongoClient
from collections import defaultdict

# 1. Connect to MongoDB
client = MongoClient("mongodb://localhost:27017/")  # or your Atlas URI
print("connection successful 0")
db = client["quiz_db"]
print("connection successful 1")
collection = db["questions"]
print("connection successful2")
# Out:
# connection successful 0
# connection successful 1
# connection successful2

# %%
# 2. Track counters per department for sequential question_id
# Check if the collection is empty to reset counters, otherwise load existing counts
if collection.count_documents({}) == 0:
    dept_counters = defaultdict(int)
else:
    # Load existing counts from the database
    dept_counters = defaultdict(int)
    for doc in collection.find({}, {"department": 1, "question_id": 1}):
        if "department" in doc and "question_id" in doc:
            dept = doc["department"][:3].upper()
            # Extract the counter part from the question_id (e.g., 'BIO-001' -> 1)
            try:
                count = int(doc["question_id"].split('-')[-1])
                if count > dept_counters[dept]:
                    dept_counters[dept] = count
            except (ValueError, IndexError):
                # Handle cases where question_id is not in expected format
                pass


# 3. Process and insert each question
for q in result.data['questions']:
    # Normalize department name
    dept_clean = q["department"].strip().title()

    # Increment per-department counter
    dept_prefix = dept_clean[:3].upper()
    dept_counters[dept_prefix] += 1

    # Build question_id (e.g., BIO-001)
    question_id = f"{dept_prefix}-{dept_counters[dept_prefix]:03d}"

    # Build public_text
    public_text = q["question_text"]
    if q["options"]:
        public_text += " Options: " + ", ".join(q["options"])

    # Final document
    doc = {
        "question_id": question_id,
        "question_text": q["question_text"],
        "options": q["options"],
        "answer": q["answer"],
        "department": dept_clean,
        "question_type": q["question_type"],
        "public_text": public_text
    }

    # Insert into MongoDB
    collection.insert_one(doc)
    print(f"Inserted {question_id} → {q['question_text']}")
# Out:
# Inserted BIO-001 → The adult human of average age and size has approximately how many quarts of blood?
# Inserted BIO-002 → Once the erythrocytes enter the blood in humans, it is estimated that they have an average lifetime of how many days.
# Inserted BIO-003 → Which mechanisms are important in the death of erythrocytes in human blood?
# Inserted BIO-004 → Surplus red blood cells, needed to meet an emergency, are MAINLY stored in what organ of the human body?
# Inserted BIO-005 → When a human donor gives a pint of blood, it usually requires how many weeks for the body RESERVE of red corpuscles to be replaced?
# Inserted BIO-006 → There are three substances found in human blood which carry oxygen and which begin with the letter "H". Name two of these substances.
# Inserted BIO-007 → The several types of white blood cells are sometimes collectively referred to as:
# Inserted BIO-008 → The condition in which there is a DECREASE in the number of white blood cells in humans is known as:
# Inserted BIO-009 → The smallest of the FORMED elements of the blood are the:
# Inserted BIO-010 → Which of the following statements concerning platelets is INCORRECT. Platelets:
# Inserted BIO-011 → What is the primary function of the platelets in human blood?
# Inserted BIO-012 → When a wound occurs in humans, the platelets in the blood activate a substance which starts the clotting process. The substance which starts the clotting is:
# Inserted BIO-013 → When looking at the cross section of the human tibia, one finds the RED marrow in the:
# Inserted BIO-014 → Lengthening of long bones in humans occurs in a particular area of the bone. This area is called the:
# Inserted BIO-015 → The part of the human brain which is an important relay station for the sensory impulses and also is the origin of many of the involuntary acts of the eye such as the narrowing of the pupil in bright light is the:
# Inserted BIO-016 → In the human brain, body temperature, metabolism, heart rate, sexual development, sleep and the body's use of fat and water are influenced by this region of the brain. This region of the brain is the:
# Inserted BIO-017 → In which cerebral lobes is the speech center located?
# Inserted BIO-018 → In most axons, the myelin sheath is interrupted at intervals of about 1 millimeter or more. These interruptions are called the:
# Inserted BIO-019 → Mosses and liverworts comprise this subdivision of plants. Name this plant subdivision.
# Inserted BIO-020 → This disease, caused by infection with the gram-negative Yersinia pestis, is transmitted by fleas from rats to humans. What is the more common name for this disease?
# Inserted BIO-021 → In the mammalian body, this element plays many important roles, such as maintaining normal muscular contraction and blood coagulation, and is the most important element of bone salt. Name this element.
# Inserted BIO-022 → What eight-letter name starting with the letter "O" is given to that branch of medical science concerned with the study of tumors?
# Inserted BIO-023 → In the more highly developed animals, such as humans, this gas is used to regulate the activity of the heart, the blood vessels, and the respiratory system. Working muscles produce a large amount of this substance. Narcosis due to this gas is characterized by mental disturbances which can include confusion, headache, low blood pressure, and hypothermia. Name this gas.
# Inserted BIO-024 → Cariology is the study of the:
# Inserted BIO-025 → The larval form of butterflies and moths is more commonly known as what?
# Inserted BIO-026 → Name the sac-like, blind pouch of the large intestine, situated below the level of the junction of the small intestine into the side of the large intestine. At the lower portion of this pouch one finds the appendix.
# Inserted BIO-027 → During the final stage of cell division, the mitotic apparatus disappears, the chromosomes become attenuated, the centrioles duplicate and split, the nuclear membrane becomes reconstituted and the nucleolus reappears. This phase of cell division is known as:
# Inserted BIO-028 → All cells of an organism find their lineage from a single fertilized cell. This single fertilized cell is called what?
# Inserted BIO-029 → Name the clear watery liquid that surrounds the brain and spinal cord and fills the four cavities or ventricles of the brain.
# Inserted BIO-030 → The order of insects which includes beetles is known as:
# Inserted BIO-031 → This major protein component of connective tissue in mammals comprises most of the organic matter of skin, tendons, bones, and teeth, and occurs as fibrous inclusions in most other body structures. Is this material:
# Inserted BIO-032 → Sickle cell anemia and Huntington's chorea are both:
# Inserted BIO-033 → In most species of Paramecium there are how many contractile vacuoles?
# Inserted BIO-034 → Name the outer portion of a stem or root, bounded externally by the epidermis, and internally by the cells of the pericycle.
# Inserted BIO-035 → Costal cartilage:
# Inserted BIO-036 → From which grandparent or grandparents did you inherit your mitochondria?
# Inserted BIO-037 → Which of the following are NOT part of a neuron?
# Inserted BIO-038 → The resting potential of a neuron is dependent on what two ions?
# Inserted BIO-039 → Which of the following is NOT a type of neuron?
# Inserted BIO-040 → Melatonin is produced by the:
# Inserted BIO-041 → Which of the following statements is TRUE of insulin?
# Inserted BIO-042 → Select the hormone INCORRECTLY paired with its target.
# Inserted BIO-043 → Which of the following tissues secrete hormones?
# Inserted BIO-044 → Which of the following structures is directly attached to the ovary?
# Inserted BIO-045 → Fertilization of the ovum by the sperm usually occurs in the:
# Inserted BIO-046 → The corpeus luteum secretes:
# Inserted BIO-047 → Which of the following does sperm NOT travel through?
# Inserted BIO-048 → The placenta in humans is derived from the:
# Inserted BIO-049 → The number of mature gametes resulting from meiosis in the female is:
# Inserted BIO-050 → Synapsis and crossing over of chromosomes occurs in which phases of meiosis?
# Inserted BIO-051 → A layer of dead skin cells is found in the:
# Inserted BIO-052 → Myelin sheaths are found:
# Inserted BIO-053 → Which of the following is an INCORRECT statement about the parasympathetic system?
# Inserted BIO-054 → Which of the following is NOT a component of the human axial skeleton?
# Inserted BIO-055 → Phalanges are found in the:
# Inserted BIO-056 → The phase of contraction of a muscle occurs when:
# Inserted BIO-057 → Select the INCORRECT statement concerning the muscular system.
# Inserted BIO-058 → Which type of muscle is a syncytium?
# Inserted BIO-059 → When the potential difference across a membrane of a neuron equals the threshold, what results?
# Inserted BIO-060 → What ions determine the resting potential of a nerve?
# Inserted BIO-061 → Which structure does NOT play a part in the motion of cells?
# Inserted BIO-062 → Bacteriophage are:
# Inserted BIO-063 → Which of the following is NOT a mode of genetic exchange within a bacterial population?
# Inserted BIO-064 → The blastula develops into the:
# Inserted BIO-065 → Tissue differentiation begins at which stage?
# Inserted BIO-066 → The nervous system develops from which germ layer?
# Inserted BIO-067 → During inspiration, the diaphragm moves:
# Inserted BIO-068 → The valve between the right ventricle and the pulmonary artery is the:
# Inserted BIO-069 → Which of the following is NOT a function of the kidney?
# Inserted BIO-070 → When CO2 (carbon dioxide) is dissolved in water, it yields a solution that:
# Inserted BIO-071 → Digestion of carbohydrates begins where?
# Inserted BIO-072 → Digestion of PROTEINS begins in which of the following human organs?
# Inserted BIO-073 → Bile has what function in digestion?
# Inserted BIO-074 → Of the following, which is a basic need of all living things?
# Inserted BIO-075 → A botanist is most likely to study:
# Inserted BIO-076 → A virus must do what to reproduce?
# Inserted BIO-077 → The chromosomes of a eukaryotic cell are located in the:
# Inserted BIO-078 → Which of the following is an example of symbiosis?
# Inserted BIO-079 → Oxygen enters the body of a grasshopper through:
# Inserted BIO-080 → A heart with a single atrium and single ventricle is a characteristic of adult:
# Inserted BIO-081 → Name the four main excretory organs identified in man.
# Inserted BIO-082 → The physical appearance and properties of an organism which is the expression of the genetic makeup is called the:
# Inserted BIO-083 → How many nucleotides make up a codon?
# Inserted BIO-084 → The complex of sugar polymers and proteins which are patchily distributed on the plasma membranes of animal cells is called
# Inserted BIO-085 → During cellular respiration, glucose is oxidized completely to what two compounds?
# Inserted BIO-086 → Organisms with cells containing two sets of parental chromosomes are called:
# Inserted BIO-087 → The type of gene interaction in which the effects of one gene override or mask the effects of other entirely different genes is called:
# Inserted BIO-088 → For which of the following creatures is fat the greatest percentage of body weight?
# Inserted BIO-089 → Which is false regarding freshwater fish?
# Inserted BIO-090 → Neutral fats, oils and waxes may be classified as:
# Inserted BIO-091 → Name three basic morphologies of bacteria.
# Inserted BIO-092 → What is the name of the 6 carbon monosaccharide that is the universal cellular fuel of plants and animals?
# Inserted BIO-093 → During which phase of the cell cycle are normal components of the cell synthesized and assembled?
# Inserted BIO-094 → Which of the following is NOT a characteristic shared by most of the members of the kingdom plantae?
# Inserted BIO-095 → If an individual has two dissimilar alleles for a trait, with regard to that trait he is said to be:
# Inserted BIO-096 → How many chromosomes per cell does a Down's Syndrome (trisomy 21) victim have?
# Inserted BIO-097 → If a male who is heterozygous for an autosomal trait mates with a female who is also heterozygous for that trait, what percent of their offspring are likely to be heterozygous for this trait as well?

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://127.0.0.1:27017", serverSelectionTimeoutMS=5000)
print(client.admin.command("ping"))
# Out:
# {'ok': 1.0}

# %%
# Extract from PDF
result = agent.extract("/content/chemistry.pdf")

# Preview structured output
print(result.data)
# Out:
# Uploading files: 100%|██████████| 1/1 [00:01<00:00,  1.60s/it]
# Creating extraction jobs: 100%|██████████| 1/1 [00:01<00:00,  1.80s/it]
# Extracting files: 100%|██████████| 1/1 [01:05<00:00, 65.06s/it]
# {'questions': [{'question_text': 'Which of following is not a Colligative property?', 'options': ['Relative lowering of vapour pressure', 'Elevation in boiling point', 'Osmotic pressure', 'Atmospheric pressure'], 'answer': 'Atmospheric pressure', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'If solute do not undergo neither association nor dissociation, its Van’t Hoff factor (i) will be', 'options': ['less than unity', 'greater than unity', 'unity', 'zero'], 'answer': 'unity', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'Who proposed the law of independent migration of ions of an electrolyte?', 'options': ['Raoult', 'Van’t Hoff', 'Kohlrausch', 'Hess'], 'answer': 'Kohlrausch', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'Units for rate constant (k) for all pseudo first order reactions is', 'options': ['mol⁻¹ L s⁻¹', 'mol⁻¹ L⁻¹ s⁻¹', 'mol L⁻¹ s⁻¹', 's⁻¹'], 'answer': 's⁻¹', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'Standard electrode potential (E°) for Hydrogen electrode is', 'options': ['0.00V', '1.00V', '0.01V', '1.01V'], 'answer': '0.00V', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'Leaching of silver and gold ores are done by', 'options': ['NaCN/KCN', 'NaOH/Na₂CO₃', 'NaCl/KCl', 'C/CO'], 'answer': 'NaCN/KCN', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'Half-life of a first order chemical reaction is 5.0 x 10⁻³ sec. What is its rate constant (k₁) value?', 'options': ['200 s⁻¹', '138.6 s⁻¹', '500 s⁻¹', '0.005 s⁻¹'], 'answer': '138.6 s⁻¹', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'Denticity of EDTA⁴⁻ is', 'options': ['four', 'six', 'two', 'one'], 'answer': 'six', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'DDT is a/an', 'options': ['pesticide', 'Insecticide', 'fungicide', 'germicide'], 'answer': 'Insecticide', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'Which artificial sweetener has limited use (only to cold foods)', 'options': ['Aspartame', 'Alitame', 'Saccharin', 'Sucralose'], 'answer': 'Aspartame', 'department': 'Chemistry', 'question_type': 'MCQ'}]}

# %%
result.data
# Out:
# {'questions': [{'question_text': 'Which of following is not a Colligative property?',
#    'options': ['Relative lowering of vapour pressure',
#     'Elevation in boiling point',
#     'Osmotic pressure',
#     'Atmospheric pressure'],
#    'answer': 'Atmospheric pressure',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'If solute do not undergo neither association nor dissociation, its Van’t Hoff factor (i) will be',
#    'options': ['less than unity', 'greater than unity', 'unity', 'zero'],
#    'answer': 'unity',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'Who proposed the law of independent migration of ions of an electrolyte?',
#    'options': ['Raoult', 'Van’t Hoff', 'Kohlrausch', 'Hess'],
#    'answer': 'Kohlrausch',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'Units for rate constant (k) for all pseudo first order reactions is',
#    'options': ['mol⁻¹ L s⁻¹', 'mol⁻¹ L⁻¹ s⁻¹', 'mol L⁻¹ s⁻¹', 's⁻¹'],
#    'answer': 's⁻¹',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'Standard electrode potential (E°) for Hydrogen electrode is',
#    'options': ['0.00V', '1.00V', '0.01V', '1.01V'],
#    'answer': '0.00V',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'Leaching of silver and gold ores are done by',
#    'options': ['NaCN/KCN', 'NaOH/Na₂CO₃', 'NaCl/KCl', 'C/CO'],
#    'answer': 'NaCN/KCN',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'Half-life of a first order chemical reaction is 5.0 x 10⁻³ sec. What is its rate constant (k₁) value?',
#    'options': ['200 s⁻¹', '138.6 s⁻¹', '500 s⁻¹', '0.005 s⁻¹'],
#    'answer': '138.6 s⁻¹',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'Denticity of EDTA⁴⁻ is',
#    'options': ['four', 'six', 'two', 'one'],
#    'answer': 'six',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'DDT is a/an',
#    'options': ['pesticide', 'Insecticide', 'fungicide', 'germicide'],
#    'answer': 'Insecticide',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'Which artificial sweetener has limited use (only to cold foods)',
#    'options': ['Aspartame', 'Alitame', 'Saccharin', 'Sucralose'],
#    'answer': 'Aspartame',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'}]}

# %%
from collections import defaultdict

dept_counters = defaultdict(int)  # keeps track of counters per department

for q in result.data['questions']:
    # Generate department prefix (e.g., BIO, GEO, MTH...)
    dept_prefix = q["department"][:3].upper()

    # Increment counter for this department
    dept_counters[dept_prefix] += 1

    # Create question_id like BIO-001
    q["question_id"] = f"{dept_prefix}-{dept_counters[dept_prefix]:03d}"

    # Add public_text for user display
    public_text = q["question_text"]
    if q["options"]:
        public_text += " Options: " + ", ".join(q["options"])
    q["public_text"] = public_text

# %%
result.data
# Out:
# {'questions': [{'question_text': 'Which of following is not a Colligative property?',
#    'options': ['Relative lowering of vapour pressure',
#     'Elevation in boiling point',
#     'Osmotic pressure',
#     'Atmospheric pressure'],
#    'answer': 'Atmospheric pressure',
#    'department': 'Chemistry',
#    'question_type': 'MCQ',
#    'question_id': 'CHE-001',
#    'public_text': 'Which of following is not a Colligative property? Options: Relative lowering of vapour pressure, Elevation in boiling point, Osmotic pressure, Atmospheric pressure'},
#   {'question_text': 'If solute do not undergo neither association nor dissociation, its Van’t Hoff factor (i) will be',
#    'options': ['less than unity', 'greater than unity', 'unity', 'zero'],
#    'answer': 'unity',
#    'department': 'Chemistry',
#    'question_type': 'MCQ',
#    'question_id': 'CHE-002',
#    'public_text': 'If solute do not undergo neither association nor dissociation, its Van’t Hoff factor (i) will be Options: less than unity, greater than unity, unity, zero'},
#   {'question_text': 'Who proposed the law of independent migration of ions of an electrolyte?',
#    'options': ['Raoult', 'Van’t Hoff', 'Kohlrausch', 'Hess'],
#    'answer': 'Kohlrausch',
#    'department': 'Chemistry',
#    'question_type': 'MCQ',
#    'question_id': 'CHE-003',
#    'public_text': 'Who proposed the law of independent migration of ions of an electrolyte? Options: Raoult, Van’t Hoff, Kohlrausch, Hess'},
#   {'question_text': 'Units for rate constant (k) for all pseudo first order reactions is',
#    'options': ['mol⁻¹ L s⁻¹', 'mol⁻¹ L⁻¹ s⁻¹', 'mol L⁻¹ s⁻¹', 's⁻¹'],
#    'answer': 's⁻¹',
#    'department': 'Chemistry',
#    'question_type': 'MCQ',
#    'question_id': 'CHE-004',
#    'public_text': 'Units for rate constant (k) for all pseudo first order reactions is Options: mol⁻¹ L s⁻¹, mol⁻¹ L⁻¹ s⁻¹, mol L⁻¹ s⁻¹, s⁻¹'},
#   {'question_text': 'Standard electrode potential (E°) for Hydrogen electrode is',
#    'options': ['0.00V', '1.00V', '0.01V', '1.01V'],
#    'answer': '0.00V',
#    'department': 'Chemistry',
#    'question_type': 'MCQ',
#    'question_id': 'CHE-005',
#    'public_text': 'Standard electrode potential (E°) for Hydrogen electrode is Options: 0.00V, 1.00V, 0.01V, 1.01V'},
#   {'question_text': 'Leaching of silver and gold ores are done by',
#    'options': ['NaCN/KCN', 'NaOH/Na₂CO₃', 'NaCl/KCl', 'C/CO'],
#    'answer': 'NaCN/KCN',
#    'department': 'Chemistry',
#    'question_type': 'MCQ',
#    'question_id': 'CHE-006',
#    'public_text': 'Leaching of silver and gold ores are done by Options: NaCN/KCN, NaOH/Na₂CO₃, NaCl/KCl, C/CO'},
#   {'question_text': 'Half-life of a first order chemical reaction is 5.0 x 10⁻³ sec. What is its rate constant (k₁) value?',
#    'options': ['200 s⁻¹', '138.6 s⁻¹', '500 s⁻¹', '0.005 s⁻¹'],
#    'answer': '138.6 s⁻¹',
#    'department': 'Chemistry',
#    'question_type': 'MCQ',
#    'question_id': 'CHE-007',
#    'public_text': 'Half-life of a first order chemical reaction is 5.0 x 10⁻³ sec. What is its rate constant (k₁) value? Options: 200 s⁻¹, 138.6 s⁻¹, 500 s⁻¹, 0.005 s⁻¹'},
#   {'question_text': 'Denticity of EDTA⁴⁻ is',
#    'options': ['four', 'six', 'two', 'one'],
#    'answer': 'six',
#    'department': 'Chemistry',
#    'question_type': 'MCQ',
#    'question_id': 'CHE-008',
#    'public_text': 'Denticity of EDTA⁴⁻ is Options: four, six, two, one'},
#   {'question_text': 'DDT is a/an',
#    'options': ['pesticide', 'Insecticide', 'fungicide', 'germicide'],
#    'answer': 'Insecticide',
#    'department': 'Chemistry',
#    'question_type': 'MCQ',
#    'question_id': 'CHE-009',
#    'public_text': 'DDT is a/an Options: pesticide, Insecticide, fungicide, germicide'},
#   {'question_text': 'Which artificial sweetener has limited use (only to cold foods)',
#    'options': ['Aspartame', 'Alitame', 'Saccharin', 'Sucralose'],
#    'answer': 'Aspartame',
#    'department': 'Chemistry',
#    'question_type': 'MCQ',
#    'question_id': 'CHE-010',
#    'public_text': 'Which artificial sweetener has limited use (only to cold foods) Options: Aspartame, Alitame, Saccharin, Sucralose'}]}

# %%
# Extract from PDF
result = agent.extract("/content/chemistry-6-53.pdf")

# Preview structured output
print(result.data)
# Out:
# Uploading files: 100%|██████████| 1/1 [00:01<00:00,  1.89s/it]
# Creating extraction jobs: 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]
# Extracting files: 100%|██████████| 1/1 [01:17<00:00, 77.82s/it]
# {'questions': [{'question_text': 'Which of the following aqueous solutions would have the highest boiling point?', 'options': ['(a) 1.0 M NaOH', '(b) 1.0 M Na₂SO₄', '(c) 1.0 M NH₄NO₃', '(d) 1.0 M KNO₃'], 'answer': '(b) 1.0 M Na₂SO₄', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'The set with the correct order of acidity is:', 'options': ['(a) HClO < HClO₂ < HClO₃ < HClO₄', '(b) HClO₄ < HClO₃ < HClO₂ < HClO', '(c) HClO₄ < HClO₃, HClO, HClO₂', '(d) HClO₃ < HClO₂ < HClO < HClO₄'], 'answer': '(a) HClO < HClO₂ < HClO₃ < HClO₄', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'Each polypeptide in a protein has amino acids linked with each other in a specific sequence. This sequence of amino acids is said to be:', 'options': ['(a) Secondary structure of Protein', '(b) Tertiary structure of Protein', '(c) Primary structure of Protein', '(d) Quaternary structure of Protein'], 'answer': '(c) Primary structure of Protein', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'Which of the following electrolytes will have maximum coagulating value for AgI/Ag⁺ sol?', 'options': ['(a) Na₂S', '(b) Na₃PO₄', '(c) Na₂SO₄', '(d) NaCl'], 'answer': '(b) Na₃PO₄', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'Which of the following alkyl halides will undergo SN1 reaction most readily?', 'options': ['(a) (CH₃)₃C-F', '(b) (CH₃)₃C-Cl', '(c) (CH₃)₃C-Br', '(d) (CH₃)₃C-I'], 'answer': '(d) (CH₃)₃C-I', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'Methylamine reacts with HNO₂ to form:', 'options': ['(a) CH₃-O-N=O', '(b) CH₃-O-CH₃', '(c) CH₃OH', '(d) CH₃CHO'], 'answer': '(c) CH₃OH', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'The quantity of charge required to obtain one mole of Aluminium from Al₂O₃ is:', 'options': ['(a) 1 F', '(b) 6 F', '(c) 3 F', '(d) 2 F'], 'answer': '(c) 3 F', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'Which of the following statements is not correct?\n(a) Terylene is a polyester polymer\n(b) Caprolactum is the monomer of Nylon - 6\n(c) Phenol Formaldehyde resin is known as Bakelite\n(d) The monomer of natural rubber is Butadiene', 'options': ['(a) Terylene is a polyester polymer', '(b) Caprolactum is the monomer of Nylon - 6', '(c) Phenol Formaldehyde resin is known as Bakelite', '(d) The monomer of natural rubber is Butadiene'], 'answer': '(d) The monomer of natural rubber is Butadiene', 'department': 'Chemistry', 'question_type': 'MCQ'}, {'question_text': 'Which of the following compounds does not undergo aldol condensation:\n(a) CH₃CHO\n(b) CH₃CH₂CHO\n(c) CH₃-C-CH₃ (with O)\n(d) CH₃-C-CHO (with CH₃)', 'options': ['(a) CH₃CHO', '(b) CH₃CH₂CHO', '(c) CH₃-C-CH₃ (with O)', '(d) CH₃-C-CHO (with CH₃)'], 'answer': '(d) CH₃-C-CHO (with CH₃)', 'department': 'Chemistry', 'question_type': 'MCQ'}]}

# %%
result.data
# Out:
# {'questions': [{'question_text': 'Which of the following aqueous solutions would have the highest boiling point?',
#    'options': ['(a) 1.0 M NaOH',
#     '(b) 1.0 M Na₂SO₄',
#     '(c) 1.0 M NH₄NO₃',
#     '(d) 1.0 M KNO₃'],
#    'answer': '(b) 1.0 M Na₂SO₄',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'The set with the correct order of acidity is:',
#    'options': ['(a) HClO < HClO₂ < HClO₃ < HClO₄',
#     '(b) HClO₄ < HClO₃ < HClO₂ < HClO',
#     '(c) HClO₄ < HClO₃, HClO, HClO₂',
#     '(d) HClO₃ < HClO₂ < HClO < HClO₄'],
#    'answer': '(a) HClO < HClO₂ < HClO₃ < HClO₄',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'Each polypeptide in a protein has amino acids linked with each other in a specific sequence. This sequence of amino acids is said to be:',
#    'options': ['(a) Secondary structure of Protein',
#     '(b) Tertiary structure of Protein',
#     '(c) Primary structure of Protein',
#     '(d) Quaternary structure of Protein'],
#    'answer': '(c) Primary structure of Protein',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'Which of the following electrolytes will have maximum coagulating value for AgI/Ag⁺ sol?',
#    'options': ['(a) Na₂S', '(b) Na₃PO₄', '(c) Na₂SO₄', '(d) NaCl'],
#    'answer': '(b) Na₃PO₄',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'Which of the following alkyl halides will undergo SN1 reaction most readily?',
#    'options': ['(a) (CH₃)₃C-F',
#     '(b) (CH₃)₃C-Cl',
#     '(c) (CH₃)₃C-Br',
#     '(d) (CH₃)₃C-I'],
#    'answer': '(d) (CH₃)₃C-I',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'Methylamine reacts with HNO₂ to form:',
#    'options': ['(a) CH₃-O-N=O', '(b) CH₃-O-CH₃', '(c) CH₃OH', '(d) CH₃CHO'],
#    'answer': '(c) CH₃OH',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'The quantity of charge required to obtain one mole of Aluminium from Al₂O₃ is:',
#    'options': ['(a) 1 F', '(b) 6 F', '(c) 3 F', '(d) 2 F'],
#    'answer': '(c) 3 F',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'Which of the following statements is not correct?\n(a) Terylene is a polyester polymer\n(b) Caprolactum is the monomer of Nylon - 6\n(c) Phenol Formaldehyde resin is known as Bakelite\n(d) The monomer of natural rubber is Butadiene',
#    'options': ['(a) Terylene is a polyester polymer',
#     '(b) Caprolactum is the monomer of Nylon - 6',
#     '(c) Phenol Formaldehyde resin is known as Bakelite',
#     '(d) The monomer of natural rubber is Butadiene'],
#    'answer': '(d) The monomer of natural rubber is Butadiene',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'},
#   {'question_text': 'Which of the following compounds does not undergo aldol condensation:\n(a) CH₃CHO\n(b) CH₃CH₂CHO\n(c) CH₃-C-CH₃ (with O)\n(d) CH₃-C-CHO (with CH₃)',
#    'options': ['(a) CH₃CHO',
#     '(b) CH₃CH₂CHO',
#     '(c) CH₃-C-CH₃ (with O)',
#     '(d) CH₃-C-CHO (with CH₃)'],
#    'answer': '(d) CH₃-C-CHO (with CH₃)',
#    'department': 'Chemistry',
#    'question_type': 'MCQ'}]}
